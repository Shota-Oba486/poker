# %%
import pickle
from ranking import rank_of_five_card
from ranking import rank_of_six_card
from ranking import rank_of_seven_card

with open('2_hand.pkl', 'rb') as f:
    dict = pickle.load(f)

def judge_2hand(player_hand):

    if player_hand[0][1] == player_hand[1][1]:
        cond0 = "same"
    else:
        cond0 = "diff"
    
    rank_to_num = {'A': 14, 'K': 13, 'Q': 12, 'J': 11, 'T': 10, '9': 9, '8': 8, '7': 7, '6': 6, '5': 5, '4': 4, '3': 3,'2': 2}
    if rank_to_num[player_hand[0][0]] <= rank_to_num[player_hand[1][0]]:
        cond1,cond2 = player_hand[0][0], player_hand[1][0]
    else:
        cond1,cond2 = player_hand[1][0], player_hand[0][0]
    return dict[(cond0,cond1,cond2)]

def decide_reward(player_hand,field_card,act_player_length,action):
    cards = player_hand + field_card
    if len(field_card) == 0:
        hand_strength = judge_2hand(player_hand)
        if action == "r":
            reward = (hand_strength - 0.5)
        if action == "c":
            reward = (hand_strength - 0.4) * 0.8
        if action == "f":
            reward = - (hand_strength - 0.4) * 0.8
    elif len(field_card) == 3:
        rank,high = rank_of_five_card(cards)[1],rank_of_five_card(cards)[2]
        hand_strength = 0.5 if rank >= 4 else 0.4 if rank >= 3 else (high/(10 **11))
        if action == "r":
            reward = (hand_strength - 0.18) * 3
        if action == "c":
            reward = (hand_strength - 0.18) * 3
        if action == "f":
            reward = - (hand_strength - 0.18) * 3
    elif len(field_card) == 4:
        high = rank_of_six_card(cards)[2]
        rank = (high // (10 ** 10))
        hand_strength = 0.5 if rank >= 4 else 0.4 if rank >= 3 else (high/(10 **11))
        if action == "r":
            reward = (hand_strength - 0.18) * 3
        if action == "c":
            reward = (hand_strength - 0.18) * 3
        if action == "f":
            reward = - (hand_strength - 0.18) * 3
    elif len(field_card) == 5:
        high = rank_of_seven_card(cards)[2]
        text = rank_of_seven_card(cards)[1]
        print(text,high)
        rank = (high // (10 ** 10))
        hand_strength = 0.5 if rank >= 4 else 0.4 if rank >= 3 else (high/(10 **11))
        if action == "r":
            reward = (hand_strength - 0.18) * 3
        if action == "c":
            reward = (hand_strength - 0.18) * 3
        if action == "f":
            reward = - (hand_strength - 0.18) * 3
    
    # if action == "r":
    #     reward = -1
    # if action == "c":
    #     reward = -1
    # if action == "f":
    #     reward = 1
    
    return reward

import random
for _ in range(10000):
    deck = [
        "As", "Ad", "Ac", "Ah",
        "Ks", "Kd", "Kc", "Kh",
        "Qs", "Qd", "Qc", "Qh",
        "Js", "Jd", "Jc", "Jh",
        "Ts", "Td", "Tc", "Th",
        "9s", "9d", "9c", "9h",
        "8s", "8d", "8c", "8h",
        "7s", "7d", "7c", "7h",
        "6s", "6d", "6c", "6h",
        "5s", "5d", "5c", "5h",
        "4s", "4d", "4c", "4h",
        "3s", "3d", "3c", "3h",
        "2s", "2d", "2c", "2h"
    ]

    random.shuffle(deck)
    player_hand = []
    player_hand.append(deck[0])
    player_hand.append(deck[1])
    field_card = []
    field_card.append(deck[2])
    field_card.append(deck[3])
    field_card.append(deck[4])
    field_card.append(deck[5])
    field_card.append(deck[6])

    reward = decide_reward(player_hand,field_card,2,"r")
    print(field_card,player_hand)
    print(reward)
# Out:
# two pair 31302120000
# ['2h', '6s', '9h', '2s', 'Kh'] ['Ks', 'Qd']
# 0.6600000000000001
# one pair 20911050400
# ['3s', '2c', '4h', 'Js', '5c'] ['9h', '9s']
# 0.08733151200000003
# one pair 21012080700
# ['2c', 'Qd', 'Th', 'Td', '7h'] ['8c', '4c']
# 0.090362421
# two pair 31411120000
# ['Js', 'Qd', 'As', '2h', 'Tc'] ['Jc', 'Ad']
# 0.6600000000000001
# one pair 20614120900
# ['4h', '9h', 'As', 'Qc', '2s'] ['6h', '6s']
# 0.078423627
# one pair 20514131200
# ['Th', 'Kc', '5c', 'Qs', 'Ad'] ['5s', '6h']
# 0.075423936
# one pair 20914130700
# ['Ks', '7s', '6s', 'Ah', '2s'] ['9c', '9d']
# 0.08742392100000002
# nothing 11311090805
# ['Jh', 'Ks', '8c', '2h', '3s'] ['9c', '5d']
# -0.20066727585
# nothing 11413110908
# ['4c', '5c', '9s', '8c', 'Kc'] ['Js', 'Ad']
# -0.19760667276
# straight 51405040302
# ['Ah', '4s', '5s', '3h', '3c'] ['2h', '8s']
# 0.96
# one pair 20914131100
# ['4c', '7d', 'Ks', 'Ah', 'Jc'] ['9h', '9d']
# 0.08742393300000001
# two pair 31204090000
# ['9h', '5h', 'Qs', 'Qd', '3h'] ['4c', '4h']
# 0.6600000000000001
# two pair 31104100000
# ['7h', 'Js', '4s', '8s', 'Jd'] ['4c', 'Th']
# 0.6600000000000001
# one pair 21413090600
# ['As', '9c', 'Ac', '6s', 'Kc'] ['4h', '2h']
# 0.10239271800000005
# nothing 11412111008
# ['Qs', 'Js', 'Tc', '8d', '5c'] ['As', '4d']
# -0.19763666975999997
# one pair 21413110700
# ['Ad', '3h', '4h', 'Ah', 'Kd'] ['Js', '7h']
# 0.10239332099999998
# nothing 11311100907
# ['5h', '7c', 'Jc', '9s', '4d'] ['Tc', 'Kd']
# -0.20066697278999995
# one pair 21214131100
# ['Qd', 'Ad', '5s', '3c', 'Qs'] ['Js', 'Kh']
# 0.09642393300000002
# nothing 11412100907
# ['7s', '5s', '4h', 'Qs', 'Tc'] ['Ac', '9c']
# -0.19763697278999998
# one pair 20314130900
# ['3d', '4c', '2c', 'Kh', '9s'] ['3s', 'Ac']
# 0.069423927
# one pair 20514121000
# ['Qs', '3h', '5s', 'Ad', 'Td'] ['5d', '2s']
# 0.07542362999999999
# two pair 30705140000
# ['Td', 'Js', '5c', '5d', '7c'] ['7h', 'Ah']
# 0.6600000000000001
# one pair 20513070600
# ['Kd', '7h', '2d', '5d', '3c'] ['6h', '5h']
# 0.07539211800000001
# one pair 20213120900
# ['2c', '8c', '9c', 'Kd', '3d'] ['2s', 'Qh']
# 0.06639362700000004
# nothing 11312110907
# ['Qs', '4d', '9h', '7c', '3c'] ['Kc', 'Jd']
# -0.20063667278999997
# one pair 21413100800
# ['5c', 'Kc', '2s', '8h', 'Ad'] ['Ah', 'Th']
# 0.10239302400000005
# nothing 11312110705
# ['Jc', '3d', '5h', 'Kd', 'Qc'] ['7c', '4c']
# -0.20063667884999997
# one pair 21014130500
# ['Kh', 'Tc', 'Ah', '3h', '2s'] ['5s', 'Th']
# 0.09042391500000002
# two pair 31405100000
# ['5h', '3h', 'As', 'Td', 'Ac'] ['5c', '7c']
# 0.6600000000000001
# nothing 11312100906
# ['Qh', '6h', 'Tc', '5c', '4c'] ['9c', 'Ks']
# -0.20063697281999998
# nothing 11413110604
# ['4h', 'Kd', '3s', '2h', 'Ah'] ['6d', 'Jc']
# -0.19760668187999997
# two pair 31405130000
# ['7h', 'Kh', 'Ac', '5c', '6h'] ['Ad', '5d']
# 0.6600000000000001
# two pair 30602130000
# ['2c', '6c', '6s', '8s', 'Qc'] ['Kh', '2d']
# 0.6600000000000001
# one pair 21213110500
# ['3c', 'Qd', '5h', 'Jc', 'Kh'] ['2c', 'Qs']
# 0.09639331499999998
# three card 40412100000
# ['Qd', '9s', '7h', '4s', 'Td'] ['4h', '4d']
# 0.96
# nothing 11208070605
# ['Qd', '5d', '6c', '7s', '3d'] ['2d', '8c']
# -0.20375788184999996
# one pair 20314110900
# ['5d', '9h', 'As', '3h', '3c'] ['2s', 'Jc']
# 0.06942332699999998
# two pair 30906140000
# ['9h', '6d', '9c', '6h', 'Js'] ['As', '7d']
# 0.6600000000000001
# one pair 21114080700
# ['Jd', '6h', '8d', '2d', '7s'] ['Ah', 'Js']
# 0.09342242100000006
# one pair 20914070600
# ['9c', '9h', '7c', 'Ad', '4d'] ['6c', '2c']
# 0.08742211800000005
# one pair 20214131100
# ['4c', 'Ac', 'Jd', '2h', '2d'] ['3d', 'Kh']
# 0.06642393299999999
# one pair 21014090600
# ['2h', 'Ts', '9d', '6d', 'Tc'] ['3h', 'Ah']
# 0.09042271799999999
# one pair 21213110700
# ['Qs', 'Kc', '4c', 'Qd', '3h'] ['Jd', '7d']
# 0.09639332100000006
# nothing 11312100904
# ['3h', 'Ts', '9h', '4d', 'Qs'] ['2d', 'Ks']
# -0.20063697288
# two pair 30604120000
# ['4d', 'Qc', '6s', '9s', 'Js'] ['6d', '4s']
# 0.6600000000000001
# one pair 21413121100
# ['Jc', 'Qh', 'Ah', '4s', 'Ac'] ['Kh', '8h']
# 0.10239363299999998
# one pair 21113100700
# ['7d', '3s', 'Th', 'Jc', 'Jd'] ['5h', 'Ks']
# 0.09339302100000005
# nothing 11412090807
# ['Qs', '6d', '9h', '8s', '7c'] ['4h', 'Ah']
# -0.19763727578999998
# one pair 21014110900
# ['4c', '9c', 'As', 'Ts', 'Th'] ['Js', '2s']
# 0.090423327
# one pair 21014121100
# ['Ad', '7h', 'Tc', 'Qd', 'Ts'] ['Jh', '3c']
# 0.090423633
# two pair 31408060000
# ['4c', '5h', '6d', '8h', 'As'] ['Ah', '8d']
# 0.6600000000000001
# nothing 11411080605
# ['Jd', '8h', '6c', 'As', '3h'] ['5d', '2c']
# -0.19766758185
# two pair 30706130000
# ['9c', '7d', '6s', 'Kh', '7c'] ['6c', '5s']
# 0.6600000000000001
# one pair 20311090800
# ['9d', '3d', '8d', '3c', '5d'] ['Js', '2h']
# 0.06933272400000004
# two pair 30604130000
# ['6c', '4h', '8c', '6s', 'Jc'] ['Ks', '4s']
# 0.6600000000000001
# two pair 31103100000
# ['3c', 'Jd', '6h', 'Js', '3h'] ['Th', '2h']
# 0.6600000000000001
# one pair 20512100900
# ['5s', '5c', 'Qh', '7h', '9s'] ['4s', 'Td']
# 0.075363027
# one pair 20914100500
# ['As', '4c', '9s', '2c', 'Ts'] ['9h', '5c']
# 0.08742301499999999
# one pair 21108060400
# ['3h', '4d', 'Jh', '6d', '2c'] ['8s', 'Jc']
# 0.09324181200000003
# nothing 11312100807
# ['Qs', 'Td', '7s', 'Ks', '8d'] ['3d', '5s']
# -0.20063697578999998
# nothing 11312100704
# ['Ts', '4c', '7c', 'Qs', '3d'] ['2d', 'Kh']
# -0.20063697887999998
# one pair 21409070500
# ['9c', '2h', 'As', '5c', 'Ah'] ['4d', '7s']
# 0.102272115
# one pair 21007060400
# ['3s', '6c', '7d', '2d', 'Tc'] ['4c', 'Ts']
# 0.090211812
# one pair 20214090700
# ['2h', '9h', '3h', '2s', '4s'] ['Ah', '7s']
# 0.06642272100000005
# one pair 21211070500
# ['Qh', '2c', '4d', 'Jc', '5d'] ['7d', 'Qd']
# 0.09633211500000005
# two pair 31103100000
# ['Jd', '3c', '3s', '9s', 'Js'] ['5d', 'Ts']
# 0.6600000000000001
# nothing 11009070605
# ['Ts', '6c', '9c', '2s', '7s'] ['5c', '4c']
# -0.20972788184999996
# two pair 31412040000
# ['Ad', 'Qs', 'As', 'Qc', '4d'] ['3d', '3h']
# 0.6600000000000001
# one pair 20310080700
# ['7c', '5h', '3c', '3h', '8s'] ['6c', 'Tc']
# 0.069302421
# one pair 21413080500
# ['5d', 'Ks', '8c', 'Ad', 'Ac'] ['4h', '3h']
# 0.10239241500000004
# one pair 20914131100
# ['Tc', '6s', '9c', 'As', '9s'] ['Jc', 'Kh']
# 0.08742393300000001
# straight 51405040302
# ['4d', '8h', '5h', '3s', '2s'] ['Ah', 'Tc']
# 0.96
# one pair 21312100700
# ['Kc', '7h', 'Kd', 'Qd', 'Tc'] ['2h', '6h']
# 0.09936302100000002
# two pair 30705120000
# ['7s', 'Qc', '7h', '9d', '2s'] ['5c', '5h']
# 0.6600000000000001
# two pair 31309080000
# ['9d', 'Kh', 'Kc', '9s', '8h'] ['8s', '5s']
# 0.6600000000000001
# two pair 30905120000
# ['9d', '5s', '5h', 'Qs', '2s'] ['9c', '4c']
# 0.6600000000000001
# one pair 21213100800
# ['3d', 'Kc', 'Qc', '4h', 'Ts'] ['8h', 'Qd']
# 0.09639302400000005
# nothing 11411090706
# ['2s', 'Js', 'Ac', '5h', '7h'] ['9s', '6h']
# -0.19766727881999996
# straight 50605040302
# ['9h', '4c', 'Jh', '5c', '2c'] ['6h', '3d']
# 0.96
# three card 40414120000
# ['4h', 'Ah', 'Qc', '4d', '9h'] ['4s', '3s']
# 0.96
# one pair 20311100800
# ['5s', '8s', '7h', 'Js', '3h'] ['3s', 'Td']
# 0.06933302400000005
# nothing 11412111009
# ['7c', '5s', 'Ah', '9h', 'Qd'] ['Ts', 'Jh']
# -0.19763666972999996
# one pair 20314100800
# ['4c', 'Ts', 'Ah', '6h', '3s'] ['8h', '3c']
# 0.06942302400000006
# flush 61310090302
# ['9d', '7s', '3d', '2d', 'Td'] ['7h', 'Kd']
# 0.96
# one pair 20813090700
# ['7d', 'Ks', '9s', '8c', '8s'] ['2s', '6d']
# 0.08439272100000003
# one pair 21410090800
# ['Tc', '8c', 'Ac', '3h', '9c'] ['Ad', '6d']
# 0.10230272400000004
# straight 50807060504
# ['7h', '6c', 'Qd', '5h', '8h'] ['Qh', '4c']
# 0.96
# one pair 21311100800
# ['Kh', '8s', 'Kc', 'Th', '5s'] ['7d', 'Js']
# 0.09933302399999999
# nothing 11110090504
# ['3d', '4d', '9d', '5s', 'Js'] ['2h', 'Tc']
# -0.20669728487999997
# one pair 21013110700
# ['Jc', 'Tc', '2c', '7h', 'Ts'] ['Kd', '6d']
# 0.09039332100000005
# three card 41413070000
# ['7c', '3d', '6s', 'As', 'Ad'] ['Kh', 'Ac']
# 0.96
# one pair 21114100800
# ['5s', '6c', '8c', 'Jh', 'Td'] ['Ac', 'Jc']
# 0.093423024
# one pair 20513120900
# ['5s', 'Kc', '2d', '9s', '4d'] ['5h', 'Qs']
# 0.07539362700000005
# one pair 21112090700
# ['6c', 'Jd', 'Qd', '7h', '9s'] ['2c', 'Jh']
# 0.09336272100000001
# two pair 31210130000
# ['Tc', 'Kc', '2d', 'Qc', '5c'] ['Qh', 'Td']
# 0.6600000000000001
# one pair 21014130800
# ['8c', '4h', 'Ts', '3h', 'Ah'] ['Ks', 'Td']
# 0.09042392400000002
# nothing 11412090706
# ['2h', '9c', '6c', '4h', 'As'] ['Qh', '7s']
# -0.19763727881999998
# nothing 11312111007
# ['2s', 'Qs', '7s', 'Jh', 'Kh'] ['3h', 'Td']
# -0.20063666978999997
# one pair 21314121000
# ['Ks', 'Td', '2h', 'Qd', '3c'] ['Kh', 'As']
# 0.09942363000000001
# two pair 30806100000
# ['8s', '2s', '6c', 'Ts', '8h'] ['5d', '6s']
# 0.6600000000000001
# straight 51211100908
# ['Jc', '8d', '3h', '2d', '9h'] ['Td', 'Qc']
# 0.96
# nothing 11412090805
# ['Ad', '4d', '8s', '9h', '5c'] ['Qc', '3d']
# -0.19763727585
# nothing 11311100805
# ['3h', 'Ks', '2d', 'Jh', '5d'] ['Tc', '8s']
# -0.20066697584999998
# three card 40314110000
# ['4d', 'Jd', '3c', '3d', '3s'] ['7d', 'Ah']
# 0.96
# nothing 11311090806
# ['Kh', '2d', '5h', '8c', '9h'] ['6h', 'Js']
# -0.20066727582
# one pair 21009070400
# ['7d', '4d', '3c', '9s', 'Th'] ['2s', 'Tc']
# 0.09027211199999999
# one pair 20611090800
# ['9d', '6c', '6d', 'Js', '2s'] ['8c', '5c']
# 0.07833272400000005
# one pair 20314121100
# ['Qd', 'Jh', '3s', '5c', 'Ah'] ['3h', '8d']
# 0.06942363299999998
# one pair 20911080700
# ['9d', '8d', '7d', '4d', 'Js'] ['2h', '9h']
# 0.08733242100000005
# one pair 21409070500
# ['Ac', '7c', '9s', 'As', '4d'] ['2d', '5c']
# 0.102272115
# one pair 21411070600
# ['2c', 'Js', '7h', 'As', '6s'] ['Ah', '4c']
# 0.10233211800000006
# one pair 20613121100
# ['Kh', '4s', '6d', 'Jc', '5h'] ['Qh', '6c']
# 0.07839363300000005
# two pair 31413040000
# ['2h', '2d', 'Ks', '4d', 'As'] ['Kh', 'Ad']
# 0.6600000000000001
# two pair 30502130000
# ['6h', '9h', '5d', 'Ks', '2h'] ['2s', '5h']
# 0.6600000000000001
# nothing 11412090807
# ['8s', '9d', '4d', '6s', 'As'] ['7c', 'Qs']
# -0.19763727578999998
# straight 51009080706
# ['8c', '7d', 'Ac', 'Ts', 'Qc'] ['9c', '6h']
# 0.96
# nothing 11312110706
# ['4c', 'Kh', '5h', 'Jc', '7c'] ['6d', 'Qh']
# -0.20063667881999997
# three card 40414120000
# ['Qh', '4c', '9d', '4h', '4d'] ['Js', 'As']
# 0.96
# nothing 11412070604
# ['4h', '7c', '3h', 'Ac', '2c'] ['6s', 'Qd']
# -0.19763788187999998
# straight 51413121110
# ['Ah', '7h', 'Th', '4d', 'Kh'] ['Qs', 'Jc']
# 0.96
# one pair 20812100500
# ['3s', 'Td', '8d', 'Qs', '8h'] ['2h', '5s']
# 0.08436301500000001
# one pair 20412100700
# ['5c', '4c', 'Th', '7c', '4d'] ['3d', 'Qs']
# 0.072363021
# two pair 31303110000
# ['3c', 'Jd', 'Ks', '8s', '3h'] ['Kc', '4s']
# 0.6600000000000001
# nothing 11413121108
# ['Ac', 'Kc', '6s', 'Jd', '2c'] ['Qs', '8h']
# -0.19760636675999999
# three card 41108050000
# ['Jd', '4d', '5d', 'Js', '8d'] ['Jh', '2s']
# 0.96
# three card 40214100000
# ['9d', '5c', '2h', '2d', 'Ac'] ['Th', '2c']
# 0.96
# one pair 21412090800
# ['5c', 'Ad', '9s', 'Ac', '6c'] ['Qs', '8c']
# 0.10236272400000002
# one pair 20912111000
# ['9d', '9c', '5h', 'Jd', '6h'] ['Td', 'Qd']
# 0.08736333000000002
# one pair 21314121100
# ['Kh', 'Jc', '9d', 'Ah', 'Qh'] ['Kc', '6h']
# 0.09942363300000001
# nothing 11110090706
# ['7c', '9h', '6d', '4c', 'Jc'] ['Tc', '2d']
# -0.20669727881999997
# nothing 11412110806
# ['Qc', 'Js', '3d', '6c', 'Ac'] ['8h', '2d']
# -0.19763667581999997
# one pair 21013110700
# ['Td', '7s', '5h', 'Th', 'Jd'] ['2c', 'Ks']
# 0.09039332100000005
# three card 41314070000
# ['Kc', 'Kd', 'Kh', '7c', '2c'] ['6h', 'Ad']
# 0.96
# two pair 30804100000
# ['8h', '4s', '8s', '9h', 'Ts'] ['4h', '6d']
# 0.6600000000000001
# nothing 11211100907
# ['7c', '6s', '9c', 'Qc', 'Th'] ['2d', 'Js']
# -0.20366697278999996
# one pair 20414130900
# ['5d', '9d', '2s', 'Ad', 'Kd'] ['4s', '4c']
# 0.072423927
# two pair 31304100000
# ['2d', '4h', 'Kh', 'Tc', 'Kd'] ['8d', '4s']
# 0.6600000000000001
# one pair 20713110800
# ['4s', '7c', '8c', 'Jh', '5d'] ['Kc', '7d']
# 0.08139332400000004
# one pair 20412080600
# ['5c', '8c', 'Qh', '4s', '3s'] ['6d', '4d']
# 0.07236241799999998
# two pair 31306050000
# ['5d', '6h', '4s', 'Kd', '2h'] ['6d', 'Ks']
# 0.6600000000000001
# three card 41210080000
# ['Qd', 'Qc', 'Qh', '6h', '8c'] ['2s', 'Tc']
# 0.96
# nothing 11009080504
# ['3s', '8s', '5h', '4c', '9s'] ['Th', '2d']
# -0.20972758487999998
# three card 40811070000
# ['Jh', '3s', '8h', '4d', '8s'] ['8d', '7c']
# 0.96
# two pair 31004120000
# ['7h', '4h', 'Td', '3d', 'Qh'] ['4d', 'Tc']
# 0.6600000000000001
# two pair 31106130000
# ['6h', '9d', 'Td', 'Jd', '6c'] ['Jc', 'Kc']
# 0.6600000000000001
# one pair 20309080700
# ['8h', '9c', '7s', '3h', '2h'] ['3d', '4h']
# 0.06927242100000006
# one pair 20613090800
# ['6d', '7c', '3h', 'Kh', '6h'] ['8d', '9h']
# 0.07839272400000002
# full house 70804000000
# ['8c', '4c', 'Kh', '4d', '5h'] ['8d', '8h']
# 0.96
# one pair 20614131100
# ['Ah', '6h', '6c', '3c', '8d'] ['Jd', 'Kc']
# 0.078423933
# two pair 31003120000
# ['5d', '3h', 'Ts', '6c', 'Qd'] ['3s', 'Th']
# 0.6600000000000001
# nothing 11413100807
# ['6h', 'Ac', 'Kc', '5c', '8s'] ['7d', 'Tc']
# -0.19760697578999997
# one pair 20814131100
# ['Kc', 'Ah', 'Jh', '8c', '8d'] ['3c', '7c']
# 0.084423933
# nothing 11310090805
# ['Ks', '2s', '5s', '4d', '9h'] ['Tc', '8d']
# -0.20069727584999997
# nothing 11211100807
# ['Th', '3h', 'Qh', 'Js', '7c'] ['8d', '2c']
# -0.20366697578999998
# two pair 31006130000
# ['6s', '6d', 'Th', '7d', 'Tc'] ['Kh', '5c']
# 0.6600000000000001
# nothing 11413120805
# ['Ah', '8s', '3c', 'Qh', '4s'] ['Kc', '5c']
# -0.19760637584999996
# one pair 20613121000
# ['6s', 'Qs', '6c', '9c', 'Tc'] ['8d', 'Kd']
# 0.07839363000000005
# flush 61309060504
# ['4s', '3h', 'Ks', '5s', '6s'] ['9s', '5c']
# 0.96
# one pair 21113090800
# ['Js', '2c', 'Kc', '9c', '8s'] ['7d', 'Jh']
# 0.09339272400000004
# three card 40414090000
# ['7s', 'As', '4s', '4d', '5s'] ['4h', '9h']
# 0.96
# two pair 30704140000
# ['4h', '3s', 'Qh', '7d', '4s'] ['7c', 'As']
# 0.6600000000000001
# one pair 20213110700
# ['2s', 'Kh', '2d', '3h', '7c'] ['6h', 'Js']
# 0.06639332100000003
# one pair 21113080700
# ['2s', 'Kc', '5s', '8c', '7s'] ['Jd', 'Jh']
# 0.09339242100000003
# two pair 31210130000
# ['Qs', 'Tc', '2c', 'Th', 'Kd'] ['Qc', '7h']
# 0.6600000000000001
# one pair 20714121100
# ['Jc', '6h', '2c', '7c', 'Ah'] ['7s', 'Qh']
# 0.081423633
# one pair 20914131200
# ['Kh', 'As', '9s', '4h', '9h'] ['Qd', '6d']
# 0.08742393600000001
# one pair 21213111000
# ['Tc', 'Qs', 'Jh', 'Ks', '5c'] ['Qc', '3d']
# 0.09639333000000005
# nothing 11310090604
# ['Tc', '9s', '3h', '6h', '2d'] ['Kc', '4s']
# -0.20069728187999997
# nothing 11413110807
# ['3h', 'Ks', 'Ac', '8h', '7h'] ['4s', 'Jd']
# -0.19760667578999996
# nothing 11412110908
# ['6c', 'Jh', '9s', 'Ad', '8c'] ['Qh', '5d']
# -0.19763667275999997
# one pair 21213090700
# ['Qd', '7s', '2s', 'Ks', '9d'] ['5c', 'Qc']
# 0.09639272100000004
# nothing 11211090605
# ['5h', '4s', '6s', '9h', 'Jh'] ['Qh', '2s']
# -0.20366728185
# nothing 11110080704
# ['Td', '4c', '8h', '3h', '7d'] ['2c', 'Jd']
# -0.20669757887999998
# one pair 21114121000
# ['5s', 'As', 'Td', 'Qs', 'Js'] ['Jh', '2d']
# 0.09342363000000001
# one pair 20212090700
# ['2d', '6s', 'Qs', '7d', '9s'] ['3d', '2s']
# 0.06636272099999999
# two pair 31403110000
# ['Jc', 'Td', '3c', '4h', 'As'] ['3h', 'Ac']
# 0.6600000000000001
# one pair 20711100900
# ['Jh', '7s', '6s', '4d', 'Td'] ['9h', '7d']
# 0.08133302700000006
# nothing 11412100804
# ['Tc', '3s', '8c', 'Qs', '2s'] ['As', '4c']
# -0.19763697587999998
# flush 61310090706
# ['4d', 'Kc', '4s', '6c', '9c'] ['Tc', '7c']
# 0.96
# flush 61009080504
# ['9h', 'Th', '2s', '3d', '5h'] ['8h', '4h']
# 0.96
# three card 40813120000
# ['Th', 'Ks', '8h', '8d', 'Qc'] ['8s', '6s']
# 0.96
# two pair 30703140000
# ['7s', 'Tc', '7h', '4s', 'Ad'] ['3h', '3s']
# 0.6600000000000001
# one pair 21213100800
# ['Qh', '8c', 'Tc', '2d', 'Qd'] ['Kc', '7h']
# 0.09639302400000005
# nothing 11311080705
# ['Kh', 'Jh', '4d', '2s', '7d'] ['5c', '8d']
# -0.20066757884999997
# one pair 20914100700
# ['3c', '9d', 'Ah', '7s', '5s'] ['Th', '9c']
# 0.08742302099999999
# one pair 20714131200
# ['7h', 'Kc', '9d', '2c', '7s'] ['Ad', 'Qc']
# 0.081423936
# one pair 21412111000
# ['Th', '2h', 'Jc', '5s', 'Qs'] ['Ac', 'As']
# 0.10236333000000003
# nothing 11311090807
# ['9s', 'Js', 'Kh', '2c', '7d'] ['8s', '5s']
# -0.20066727579
# one pair 21014131200
# ['Tc', 'Td', 'As', '2s', 'Qh'] ['Kh', '5s']
# 0.09042393600000001
# one pair 20814120900
# ['Qs', 'Ac', '7c', '2h', '8c'] ['8s', '9s']
# 0.084423627
# one pair 20913111000
# ['Td', '5c', 'Jh', 'Kh', '4d'] ['9c', '9s']
# 0.08739333000000005
# nothing 11412100806
# ['3d', '8h', 'As', 'Td', '6h'] ['2c', 'Qd']
# -0.19763697581999998
# two pair 31006110000
# ['5h', '6d', '6s', '8s', 'Tc'] ['Jh', 'Td']
# 0.6600000000000001
# two pair 31107090000
# ['Jc', '7d', '9d', '7s', '5d'] ['8c', 'Jh']
# 0.6600000000000001
# three card 41311100000
# ['Jd', 'Kd', '6h', 'Kc', 'Kh'] ['Td', '5h']
# 0.96
# one pair 20613121100
# ['Js', '2c', 'Tc', 'Kc', '6d'] ['Qs', '6s']
# 0.07839363300000005
# one pair 21213110800
# ['Jh', 'Qh', '5h', '8c', 'Qd'] ['Kd', '7h']
# 0.09639332400000006
# one pair 20213121000
# ['8d', 'Qd', '2h', 'Ts', 'Kd'] ['6h', '2c']
# 0.06639363000000004
# nothing 11309080706
# ['9s', '4s', '8s', 'Kd', '2h'] ['7d', '6d']
# -0.20072757881999997
# one pair 20514120800
# ['As', '8d', '5d', '2d', '7s'] ['5s', 'Qh']
# 0.075423624
# two pair 31303120000
# ['Qh', 'Kh', '3c', 'Td', 'Kd'] ['4d', '3d']
# 0.6600000000000001
# three card 41209080000
# ['8c', 'Qh', '9s', 'Qc', 'Qd'] ['2h', '5d']
# 0.96
# one pair 21311090800
# ['8d', 'Ks', 'Jh', '2s', '4c'] ['Kc', '9d']
# 0.09933272399999998
# straight 50807060504
# ['7c', '7s', '5c', 'Qs', '8c'] ['6s', '4c']
# 0.96
# two pair 31108140000
# ['Td', '8c', 'Ah', '8d', '5h'] ['Jh', 'Jd']
# 0.6600000000000001
# one pair 21310090800
# ['4c', '9c', 'Kh', 'Ks', 'Tc'] ['5c', '8d']
# 0.09930272400000004
# nothing 11412111006
# ['Th', 'Ac', '3c', 'Jd', '6c'] ['4c', 'Qs']
# -0.19763666981999997
# two pair 30402120000
# ['Th', 'Qh', '2c', '7c', '4s'] ['2h', '4h']
# 0.6600000000000001
# full house 70714000000
# ['7c', 'Ad', 'Ah', '7d', '5h'] ['2h', '7s']
# 0.96
# straight 51211100908
# ['2s', 'Jh', '2d', 'Th', 'Qs'] ['9d', '8s']
# 0.96
# one pair 21312111000
# ['Qc', '5s', 'Kh', 'Jd', 'Td'] ['Kc', '8c']
# 0.09936333000000003
# nothing 11413111009
# ['Js', 'Ah', '4d', 'Kh', '2s'] ['Td', '9d']
# -0.19760666972999996
# nothing 11413110908
# ['Kh', '8h', '6s', '9c', '4s'] ['Jh', 'As']
# -0.19760667276
# two pair 31003120000
# ['Td', '3h', 'Jh', 'Ts', 'Qc'] ['7h', '3d']
# 0.6600000000000001
# two pair 31106080000
# ['Jh', 'Js', '6h', '8h', '7d'] ['4s', '6s']
# 0.6600000000000001
# two pair 30602140000
# ['2c', '6s', '6d', 'Ad', '3h'] ['2d', 'Ks']
# 0.6600000000000001
# one pair 20912110700
# ['7s', '6d', '2c', '9s', '9h'] ['Qs', 'Jc']
# 0.08736332100000002
# flush 61410090807
# ['Tc', '7c', '5s', '9c', '3c'] ['Ac', '8c']
# 0.96
# one pair 20513120900
# ['5h', '5d', '8c', '9d', '6d'] ['Qh', 'Kd']
# 0.07539362700000005
# one pair 20414100800
# ['3h', '7h', '8d', '4d', '4h'] ['Tc', 'Ah']
# 0.07242302400000006
# one pair 20714130900
# ['3d', '7h', '5c', '9d', 'Kh'] ['Ah', '7s']
# 0.08142392700000001
# nothing 11310090807
# ['7d', '5h', '8s', 'Kh', '4d'] ['Td', '9d']
# -0.20069727578999996
# one pair 20714121000
# ['7c', '7d', 'Tc', 'As', '5d'] ['3d', 'Qc']
# 0.08142363
# straight 51110090807
# ['9d', 'Jc', '8h', '5h', '6d'] ['Td', '7c']
# 0.96
# two pair 30602140000
# ['2d', 'Qd', '6c', 'Jc', 'As'] ['6d', '2c']
# 0.6600000000000001
# one pair 20813100500
# ['5d', 'Kh', '8d', 'Th', '8c'] ['2c', '3h']
# 0.08439301500000004
# one pair 21012090500
# ['Td', 'Th', 'Qd', '9h', '3c'] ['5c', '2d']
# 0.09036271500000001
# one pair 20413120800
# ['4s', 'Qs', '4d', '2d', '7s'] ['8c', 'Kc']
# 0.07239362400000005
# one pair 21013080700
# ['Ts', '8h', 'Th', '2c', 'Ks'] ['3c', '7c']
# 0.09039242100000003
# one pair 21411090600
# ['Ah', '5c', 'Jd', '3d', 'Ac'] ['6h', '9s']
# 0.10233271799999999
# one pair 20414131100
# ['Kd', '4c', '7c', 'Ah', 'Jc'] ['4s', 'Td']
# 0.072423933
# one pair 20312111000
# ['Qc', '3c', '2h', 'Ts', '3s'] ['9h', 'Jh']
# 0.06936333
# straight 51413121110
# ['Tc', 'Js', 'As', '4c', '9h'] ['Ks', 'Qh']
# 0.96
# one pair 21413070400
# ['Kh', 'Ad', '7s', '2c', '4c'] ['3s', 'Ac']
# 0.10239211200000004
# two pair 30504080000
# ['3s', '5h', '4c', '7h', '5d'] ['4d', '8h']
# 0.6600000000000001
# one pair 21211090800
# ['7s', '8d', '9c', 'Jd', '4d'] ['Qh', 'Qd']
# 0.09633272399999998
# one pair 20711100900
# ['5d', 'Jc', '9d', '7h', 'Th'] ['7d', '4h']
# 0.08133302700000006
# nothing 11410080704
# ['Tc', '2s', '3h', '7d', 'Ac'] ['8c', '4h']
# -0.19769757887999997
# straight 50807060504
# ['6d', 'Qc', '7c', '8s', '4c'] ['5c', 'Kd']
# 0.96
# one pair 20913120500
# ['9d', 'Qd', '2s', '9s', 'Kd'] ['5s', '3d']
# 0.08739361499999998
# nothing 11210090605
# ['5c', '2h', '3h', '9s', '6c'] ['Qs', 'Td']
# -0.20369728184999997
# nothing 11412090806
# ['9d', 'As', '8s', '2s', '6d'] ['3h', 'Qh']
# -0.19763727581999999
# nothing 11412110906
# ['9d', 'Qh', '6s', 'Js', '2c'] ['As', '3h']
# -0.19763667281999997
# nothing 11412080605
# ['Qs', '3c', '5d', 'As', '8s'] ['6s', '4d']
# -0.19763758185
# nothing 11413080706
# ['6h', '7s', '3h', '8c', 'Kh'] ['Ad', '2c']
# -0.19760757881999996
# one pair 20814120700
# ['8c', 'Qs', '8h', '6h', '7c'] ['5h', 'Ad']
# 0.084423621
# two pair 31004130000
# ['2c', 'Tc', 'Th', 'Kd', '4c'] ['7d', '4h']
# 0.6600000000000001
# two pair 31411100000
# ['Jc', 'Th', 'Ad', 'Js', '4h'] ['4c', 'As']
# 0.6600000000000001
# two pair 30503140000
# ['5s', 'Qs', '3d', 'Jh', '3c'] ['5h', 'Ad']
# 0.6600000000000001
# one pair 21410080700
# ['2d', 'Ts', '7c', 'Ah', '8s'] ['As', '4s']
# 0.10230242100000003
# two pair 30704140000
# ['4h', '4c', 'Ts', '5c', 'Ah'] ['7c', '7s']
# 0.6600000000000001
# nothing 11411090807
# ['Ah', 'Jd', '3h', '8s', '7h'] ['6c', '9c']
# -0.19766727578999999
# two pair 31208100000
# ['Th', '2h', '8c', 'Qs', '8s'] ['Qh', '3c']
# 0.6600000000000001
# two pair 31412110000
# ['Jc', '6d', '2s', 'Qs', 'Qh'] ['Ad', 'Ac']
# 0.6600000000000001
# nothing 11411100907
# ['Jh', 'Ah', '6h', '9c', '3h'] ['7d', 'Td']
# -0.19766697278999995
# nothing 11412110906
# ['As', '6d', 'Qd', '5d', 'Jd'] ['4h', '9h']
# -0.19763667281999997
# nothing 11413070605
# ['5s', 'Kc', '4c', '2h', '7d'] ['As', '6h']
# -0.19760788184999997
# two pair 30906120000
# ['6c', '6d', '3c', '9d', '9h'] ['Ts', 'Qd']
# 0.6600000000000001
# straight 51211100908
# ['8c', 'Qs', '9h', 'Js', 'Td'] ['2c', '6d']
# 0.96
# one pair 20214131000
# ['Kc', '6s', 'Tc', 'As', '3d'] ['2d', '2h']
# 0.06642392999999999
# three card 41210090000
# ['5d', '9d', 'Qd', 'Qs', 'Qh'] ['Ts', '8c']
# 0.96
# one pair 20414090800
# ['9c', 'Ad', '4h', '4s', '3c'] ['5c', '8c']
# 0.07242272400000005
# one pair 21114131200
# ['8d', 'As', 'Js', 'Ks', 'Jc'] ['7h', 'Qd']
# 0.09342393600000001
# one pair 20714130600
# ['4s', '7h', '6d', 'Kc', 'Ad'] ['7s', '3h']
# 0.08142391800000001
# one pair 21114130600
# ['6s', '4h', 'Jd', 'Jc', '2h'] ['As', 'Ks']
# 0.09342391800000002
# one pair 20213090800
# ['2h', '3s', '2d', 'Kd', '8c'] ['9d', '7d']
# 0.06639272400000001
# three card 40914110000
# ['5s', '9h', 'Js', 'Ac', '9s'] ['6h', '9c']
# 0.96
# two pair 31002090000
# ['Th', '2c', '2s', '6d', 'Tc'] ['4c', '9d']
# 0.6600000000000001
# two pair 31303090000
# ['3c', 'Kc', '3h', '9h', '4s'] ['Kh', '5s']
# 0.6600000000000001
# one pair 20514131000
# ['Th', '7s', '3c', '5c', '5d'] ['Ad', 'Kc']
# 0.07542393
# one pair 20214130900
# ['2d', 'Ac', 'Kh', '9d', '8c'] ['5c', '2s']
# 0.066423927
# one pair 21311090800
# ['7c', 'Js', '2s', 'Kd', '8h'] ['Kh', '9h']
# 0.09933272399999998
# one pair 21007060400
# ['2c', 'Ts', '7d', '4s', '6s'] ['Th', '3c']
# 0.090211812
# two pair 31412050000
# ['2h', 'Ac', 'Qc', '5s', 'As'] ['2d', 'Qh']
# 0.6600000000000001
# two pair 31007110000
# ['4d', '7d', 'Ts', 'Jc', '2c'] ['Tc', '7c']
# 0.6600000000000001
# nothing 11210070504
# ['3s', '4c', 'Ts', '2h', 'Qs'] ['5s', '7h']
# -0.20369788487999999
# one pair 20912070600
# ['2c', 'Qd', '7s', '6d', '9d'] ['9c', '3s']
# 0.08736211799999999
# two pair 30804120000
# ['4c', '8s', '4s', 'Td', 'Qd'] ['8c', '9d']
# 0.6600000000000001
# two pair 31109120000
# ['Qd', 'Js', 'Jh', '9s', '9c'] ['Tc', '7s']
# 0.6600000000000001
# one pair 21113090800
# ['9d', '8h', 'Jc', '7c', 'Jh'] ['Ks', '5d']
# 0.09339272400000004
# two pair 31408070000
# ['As', '7c', '8c', '8d', 'Ad'] ['6h', '5s']
# 0.6600000000000001
# one pair 21413080600
# ['5s', '8c', '6h', 'Ad', '4s'] ['Ac', 'Kc']
# 0.10239241800000004
# one pair 20414131200
# ['6h', '4s', 'Tc', 'Kc', 'Qc'] ['4h', 'Ac']
# 0.072423936
# flush 61311080604
# ['8d', 'Kd', 'Jh', '6d', '4d'] ['Jd', '6s']
# 0.96
# nothing 11411090807
# ['8h', 'As', '2c', '7d', '9c'] ['5c', 'Jd']
# -0.19766727578999999
# one pair 20714131100
# ['7d', 'Kh', '7h', 'Ad', '4s'] ['Jc', '5s']
# 0.081423933
# one pair 20913121000
# ['Qh', '9c', '9s', '8c', 'Th'] ['Kc', '7c']
# 0.08739363000000006
# two pair 31402130000
# ['Ah', 'Kc', '2d', 'Ac', 'Jd'] ['8s', '2s']
# 0.6600000000000001
# straight 50908070605
# ['Qd', 'Jc', '7d', '8h', '9s'] ['5h', '6c']
# 0.96
# straight 50908070605
# ['9c', '4c', '7d', '5h', '9h'] ['6h', '8d']
# 0.96
# one pair 20714121100
# ['8d', 'Ah', 'Js', '3s', 'Qd'] ['7d', '7s']
# 0.081423633
# nothing 11210090706
# ['7d', '6c', '9c', 'Qd', '4h'] ['Tc', '2h']
# -0.20369727881999997
# one pair 21014110700
# ['2h', 'Ac', '7c', 'Tc', 'Jd'] ['4h', 'Ts']
# 0.090423321
# full house 70408000000
# ['8d', '4s', '3d', '4d', 'Ks'] ['8s', '4c']
# 0.96
# nothing 11211090805
# ['2d', '5c', 'Jh', '8c', '9c'] ['Qc', '3h']
# -0.20366727585
# nothing 11312110904
# ['Qd', '9d', 'Js', '3h', '2c'] ['4c', 'Ks']
# -0.20063667287999998
# two pair 30706110000
# ['6h', '6d', '7d', 'Jc', '3h'] ['Td', '7h']
# 0.6600000000000001
# one pair 21412111000
# ['Tc', 'Jd', '2h', '3d', 'Qd'] ['Ah', 'Ad']
# 0.10236333000000003
# two pair 31003140000
# ['Td', '4d', '6h', '3d', 'Ah'] ['Th', '3s']
# 0.6600000000000001
# nothing 11410090807
# ['7h', '9s', 'Ah', '3c', 'Td'] ['8h', '4h']
# -0.19769727578999996
# two pair 30504140000
# ['4s', 'As', '4d', '5c', '8c'] ['9s', '5h']
# 0.6600000000000001
# one pair 20510080700
# ['7c', '5h', 'Th', '6c', '5s'] ['2d', '8h']
# 0.07530242100000001
# two pair 30604070000
# ['4d', '6s', '6c', '7h', '4s'] ['2d', '2c']
# 0.6600000000000001
# two pair 31406120000
# ['Ad', '5d', 'Js', 'Qd', '6s'] ['Ah', '6d']
# 0.6600000000000001
# three card 40513090000
# ['5s', '6d', '5c', 'Kc', '5h'] ['2d', '9d']
# 0.96
# three card 41312110000
# ['Tc', 'Ks', 'Qh', 'Kc', 'Kd'] ['4d', 'Js']
# 0.96
# one pair 20213120800
# ['Kc', '6c', '3h', 'Qd', '2d'] ['2h', '8s']
# 0.06639362400000004
# two pair 30807110000
# ['8s', '7c', '8d', '7h', 'Jc'] ['5d', '3h']
# 0.6600000000000001
# straight 51312111009
# ['Jc', 'Qd', 'Kc', '4c', '9d'] ['Td', '8d']
# 0.96
# two pair 31210110000
# ['Qs', '6d', 'Qh', 'Th', 'Jh'] ['3h', 'Td']
# 0.6600000000000001
# two pair 31412110000
# ['9h', 'Qc', 'As', 'Ah', 'Jh'] ['Ts', 'Qd']
# 0.6600000000000001
# nothing 11413120906
# ['Kd', '6d', '2h', 'Qh', 'As'] ['9s', '4d']
# -0.19760637282
# one pair 20614080500
# ['Ad', '3h', '6c', '4s', '8s'] ['6d', '5c']
# 0.07842241500000005
# one pair 21312100700
# ['5h', 'Ks', 'Kd', 'Qh', '7s'] ['Td', '4h']
# 0.09936302100000002
# one pair 20413111000
# ['3s', '4s', 'Jd', '4h', 'Kh'] ['7c', 'Ts']
# 0.07239333000000003
# two pair 31406100000
# ['Ts', '6d', 'Ad', '6h', '4c'] ['2d', 'Ah']
# 0.6600000000000001
# three card 40813050000
# ['8d', '5h', '3h', '4d', 'Kd'] ['8c', '8h']
# 0.96
# nothing 11410080706
# ['Th', '3d', '7d', '8s', '6c'] ['5d', 'Ac']
# -0.19769757881999997
# nothing 11410090706
# ['7s', 'Td', 'Ad', '2c', '6s'] ['5d', '9d']
# -0.19769727881999996
# flush 61413120908
# ['8h', 'Ah', 'Qh', 'Kh', '2d'] ['9h', '7s']
# 0.96
# one pair 20210090700
# ['5s', '2s', 'Tc', '7h', '9s'] ['2c', '6h']
# 0.06630272100000001
# one pair 20213121000
# ['8c', '2h', '7s', '2c', 'Qh'] ['Kc', 'Tc']
# 0.06639363000000004
# one pair 20614111000
# ['Ac', '5h', 'Jh', '6h', 'Td'] ['6s', '8h']
# 0.07842332999999999
# flush 61411100605
# ['7h', '8c', '6d', 'Ad', 'Jd'] ['Td', '5d']
# 0.96
# nothing 11412110907
# ['Qd', '5s', 'Ah', '4h', '7s'] ['9d', 'Jd']
# -0.19763667278999997
# one pair 20712090500
# ['2s', '3h', '9d', '5d', '7c'] ['Qc', '7h']
# 0.081362715
# nothing 11312111005
# ['Jd', '3h', '5h', 'Kh', 'Ts'] ['Qd', '4h']
# -0.20063666984999998
# one pair 20310090800
# ['9c', '3h', 'Th', '8h', '5h'] ['4c', '3c']
# 0.06930272400000001
# one pair 21412110900
# ['Ac', 'Qs', '9h', 'Ah', '3d'] ['6c', 'Jh']
# 0.10236332700000003
# two pair 30502140000
# ['5s', '9d', 'Tc', 'Ad', '2s'] ['5c', '2c']
# 0.6600000000000001
# one pair 20614131000
# ['Ad', '5s', '7s', 'Kd', 'Td'] ['6s', '6d']
# 0.07842393
# two pair 30705130000
# ['6c', '7h', '5d', 'Ks', 'Jh'] ['5s', '7c']
# 0.6600000000000001
# one pair 20313120900
# ['Kh', '3s', 'Qd', '3h', '5h'] ['7d', '9d']
# 0.06939362700000004
# three card 41009070000
# ['Tc', '7h', '4h', 'Ts', '2d'] ['Td', '9d']
# 0.96
# two pair 30807140000
# ['3s', '9d', 'Ah', '8h', '8c'] ['7h', '7c']
# 0.6600000000000001
# two pair 31102120000
# ['2d', 'Jc', '8d', 'Qh', '2c'] ['Jd', '7s']
# 0.6600000000000001
# flush 61312070604
# ['4c', '7h', '7c', 'Qc', '2s'] ['6c', 'Kc']
# 0.96
# one pair 20214090800
# ['6c', 'Ac', '2d', '8d', '2s'] ['9d', '5c']
# 0.06642272400000004
# two pair 31107120000
# ['7d', 'Qs', 'Jh', '7h', '2c'] ['Jc', '9h']
# 0.6600000000000001
# one pair 20514100700
# ['Ad', '5d', '2c', '7s', '5s'] ['4c', 'Td']
# 0.07542302099999998
# two pair 31409110000
# ['Ac', 'Jc', 'Ad', '2s', '4h'] ['9d', '9s']
# 0.6600000000000001
# two pair 30603090000
# ['3d', '9s', '3c', '6d', '4s'] ['6s', '5c']
# 0.6600000000000001
# three card 40812060000
# ['3c', '8d', '6c', 'Qc', '8c'] ['4h', '8h']
# 0.96
# one pair 20612100700
# ['Qh', '3h', '6c', 'Th', '6d'] ['5c', '7d']
# 0.078363021
# straight 50908070605
# ['8h', '3h', '5s', '6h', '9s'] ['7d', '2d']
# 0.96
# one pair 20814130600
# ['3s', '8c', '2s', '6c', 'Kh'] ['8d', 'Ah']
# 0.08442391800000001
# two pair 31208110000
# ['Td', '8h', 'Qc', 'Js', 'Qs'] ['3s', '8c']
# 0.6600000000000001
# nothing 11211090805
# ['4c', '3h', '8s', '9d', 'Jc'] ['5d', 'Qh']
# -0.20366727585
# one pair 21410070600
# ['6h', 'Ah', 'As', '3h', 'Tc'] ['7s', '2d']
# 0.10230211800000003
# one pair 20414090800
# ['9c', '8s', '4d', '4c', 'As'] ['7s', '3s']
# 0.07242272400000005
# one pair 20714121100
# ['5h', '7s', 'Qc', 'Ad', '7c'] ['6d', 'Jc']
# 0.081423633
# one pair 20714131100
# ['8c', 'Jd', '7h', '3h', 'Kd'] ['7c', 'Ac']
# 0.081423933
# one pair 21312100800
# ['Tc', 'Qh', 'Kd', '6c', '7c'] ['8s', 'Ks']
# 0.09936302400000002
# full house 70503000000
# ['3s', '5c', '8s', '5d', '3c'] ['6h', '5h']
# 0.96
# one pair 21410060500
# ['Ah', 'Td', '4h', '6d', '3h'] ['Ad', '5s']
# 0.10230181500000002
# nothing 11210090805
# ['3s', '2c', '8h', '9d', '5c'] ['Td', 'Qh']
# -0.20369727584999997
# nothing 11210090706
# ['6h', 'Tc', '4d', 'Qc', '7s'] ['9h', '5c']
# -0.20369727881999997
# two pair 31203110000
# ['Jd', 'Qh', '3d', '8h', 'Td'] ['3s', 'Qd']
# 0.6600000000000001
# nothing 11412111008
# ['Ah', 'Qs', '8s', 'Td', '3c'] ['Jd', '6d']
# -0.19763666975999997
# nothing 11312111008
# ['Jh', 'Kc', '7c', '2c', 'Qh'] ['Th', '8s']
# -0.20063666975999997
# two pair 31109060000
# ['4s', '6d', '9d', 'Jc', 'Js'] ['3h', '9h']
# 0.6600000000000001
# one pair 20213090700
# ['5s', '6s', '2h', 'Kd', '7d'] ['9c', '2c']
# 0.06639272100000002
# one pair 21410090700
# ['5c', '3h', '9s', 'Ah', 'Ad'] ['7s', 'Tc']
# 0.10230272100000004
# one pair 20212111000
# ['Qh', '2h', '9s', 'Th', '2s'] ['7c', 'Jc']
# 0.06636333
# two pair 31413110000
# ['Kd', 'Ac', 'Ad', '9s', 'Kh'] ['6c', 'Jd']
# 0.6600000000000001
# one pair 21214100700
# ['Ts', 'Qc', 'Qd', 'Ac', '7s'] ['5d', '3s']
# 0.096423021
# one pair 20314131200
# ['Qs', 'Ad', '4h', '2d', 'Kh'] ['3h', '3s']
# 0.06942393599999999
# one pair 21312060500
# ['Qs', '6c', '5h', 'Ks', 'Kd'] ['4d', '3h']
# 0.09936181499999999
# two pair 31402090000
# ['Ac', 'Ad', '5d', '9c', '2c'] ['6s', '2h']
# 0.6600000000000001
# two pair 31312110000
# ['Qh', '8c', 'Qd', '9c', 'Jh'] ['Ks', 'Kc']
# 0.6600000000000001
# one pair 20212111000
# ['8d', '4h', 'Th', 'Jc', '2c'] ['2h', 'Qc']
# 0.06636333
# one pair 21110090700
# ['7d', 'Jd', 'Jh', '5s', '9h'] ['Tc', '3c']
# 0.09330272100000003
# nothing 11413111007
# ['Js', '2s', 'Td', 'As', '7s'] ['4h', 'Kd']
# -0.19760666978999997
# two pair 30904140000
# ['Jc', '9s', 'Ac', '4s', '2c'] ['9h', '4d']
# 0.6600000000000001
# straight 51312111009
# ['Jc', 'Ts', 'Qc', 'Qs', 'Kd'] ['2s', '9h']
# 0.96
# one pair 20811100400
# ['Ts', '8d', 'Jh', '3d', '8h'] ['4c', '2d']
# 0.08433301199999998
# straight 50908070605
# ['Kd', '5d', 'Qc', '6s', '7c'] ['8h', '9h']
# 0.96
# one pair 21410070500
# ['Td', 'Ad', '4h', '5c', '2d'] ['As', '7c']
# 0.10230211500000003
# three card 40213120000
# ['6c', 'Kd', 'Th', '2d', '2h'] ['2s', 'Qd']
# 0.96
# nothing 11412110908
# ['Qs', '7d', '5c', 'Ac', '9h'] ['Js', '8h']
# -0.19763667275999997
# one pair 21114090500
# ['2h', '3s', 'Js', '5h', 'Ac'] ['9c', 'Jc']
# 0.09342271499999999
# two pair 31302110000
# ['Kd', '2d', 'Kc', '2h', '8d'] ['3h', 'Jh']
# 0.6600000000000001
# nothing 11312110907
# ['Jc', '9s', '7h', '4s', 'Qs'] ['Kc', '2d']
# -0.20063667278999997
# flush 61110090403
# ['4s', 'Ts', '8d', 'Js', '3s'] ['3h', '9s']
# 0.96
# one pair 20612100400
# ['3s', 'Th', '4d', '2d', '6c'] ['6s', 'Qc']
# 0.07836301200000001
# one pair 21014121100
# ['Tc', 'Jc', 'Ad', '3d', 'Qd'] ['8h', 'Td']
# 0.090423633
# two pair 30904070000
# ['3h', '4c', '4h', '6h', '9s'] ['9h', '7c']
# 0.6600000000000001
# nothing 11411080704
# ['4d', '8s', 'Ad', 'Js', '3h'] ['2h', '7h']
# -0.19766757887999997
# one pair 21114090700
# ['7h', '9s', '4d', 'Jc', '5h'] ['Ad', 'Js']
# 0.09342272099999999
# one pair 20714131000
# ['Ad', '7h', 'Td', '5h', '3c'] ['Kd', '7d']
# 0.08142393
# one pair 20814121100
# ['8h', 'Ad', 'Js', '5s', '8d'] ['Qc', '6h']
# 0.084423633
# one pair 20213121000
# ['4c', '2h', 'Ts', '2c', 'Kc'] ['9d', 'Qs']
# 0.06639363000000004
# nothing 11413111009
# ['As', '5h', '2d', 'Jc', 'Kc'] ['Th', '9s']
# -0.19760666972999996
# nothing 11412111009
# ['Qs', '7c', '5h', '9h', 'Ac'] ['Jc', 'Th']
# -0.19763666972999996
# one pair 20614110700
# ['7c', '2s', '6s', '5d', '6c'] ['Jc', 'As']
# 0.07842332099999999
# two pair 31003130000
# ['7s', 'Kd', 'Td', '3d', 'Tc'] ['9h', '3h']
# 0.6600000000000001
# one pair 20314130800
# ['As', '8d', '3h', 'Kc', '4s'] ['7c', '3d']
# 0.069423924
# one pair 21114090800
# ['3h', 'Ad', '9d', 'Js', 'Jc'] ['8h', '7s']
# 0.09342272399999998
# one pair 20613121000
# ['Tc', '9s', '6s', '6h', 'Kc'] ['Qc', '4d']
# 0.07839363000000005
# one pair 20512090800
# ['8s', '5d', 'Qh', '9s', '2c'] ['4s', '5s']
# 0.07536272399999999
# one pair 20213110900
# ['Jh', '3d', '2d', '2h', 'Kh'] ['8s', '9d']
# 0.06639332700000003
# nothing 11412100806
# ['Qs', '3d', '6s', '5s', 'Ts'] ['8d', 'Ad']
# -0.19763697581999998
# one pair 21113120900
# ['Kc', '9s', 'Jh', '2d', 'Qh'] ['Js', '6s']
# 0.09339362699999998
# nothing 11311090807
# ['4d', 'Kc', '8s', '7d', '6c'] ['9s', 'Js']
# -0.20066727579
# two pair 30705090000
# ['7h', '5h', '4c', '9h', '7c'] ['5c', '8h']
# 0.6600000000000001
# one pair 20612100800
# ['Qh', '8s', '6s', 'Th', '6h'] ['7d', '4s']
# 0.078363024
# one pair 20314111000
# ['Ts', 'Ah', '3s', '6h', 'Jc'] ['3d', '9c']
# 0.06942333000000006
# nothing 11312100806
# ['Qs', 'Td', 'Kh', '5d', '2c'] ['8s', '6s']
# -0.20063697581999998
# two pair 30903100000
# ['9s', '3c', '9c', '8h', '5h'] ['3d', 'Ts']
# 0.6600000000000001
# one pair 21113120800
# ['Kh', '4d', 'Js', '8s', 'Jc'] ['5h', 'Qc']
# 0.09339362399999998
# three card 40212100000
# ['7h', '2d', '6s', '2h', 'Qh'] ['Td', '2c']
# 0.96
# one pair 21014131200
# ['Tc', '9s', 'Qs', '8h', 'As'] ['Th', 'Ks']
# 0.09042393600000001
# nothing 11413121108
# ['6c', 'Ks', 'As', '8s', 'Jc'] ['Qh', '3d']
# -0.19760636675999999
# one pair 20310090800
# ['2c', '9c', 'Td', '6h', '8d'] ['3d', '3h']
# 0.06930272400000001
# two pair 31406080000
# ['6s', '4h', 'As', '6d', '8s'] ['Ah', '3h']
# 0.6600000000000001
# three card 40513110000
# ['7c', '2s', 'Kc', '5c', '5s'] ['5d', 'Jd']
# 0.96
# three card 40311090000
# ['2h', '3h', '9d', '3s', '6d'] ['Jd', '3c']
# 0.96
# nothing 11413120805
# ['2h', '3s', 'As', 'Kc', '8c'] ['Qs', '5c']
# -0.19760637584999996
# straight 50706050403
# ['Ks', '6c', 'As', '3s', '4c'] ['5s', '7d']
# 0.96
# one pair 21413121100
# ['Qd', '6h', '5d', 'Kd', 'Jh'] ['As', 'Ac']
# 0.10239363299999998
# nothing 11210070604
# ['3d', '7d', 'Td', '6c', '4h'] ['Qd', '2s']
# -0.20369788188
# two pair 30906130000
# ['Kh', '6c', 'Th', '9c', '9d'] ['2s', '6s']
# 0.6600000000000001
# one pair 20313100800
# ['8h', 'Kh', '5h', 'Tc', '2h'] ['3d', '3s']
# 0.06939302400000003
# one pair 21011090700
# ['Td', '6h', 'Ts', '2s', '7s'] ['9s', 'Jc']
# 0.09033272100000006
# one pair 21114090700
# ['6h', '9h', 'Ah', 'Jc', 'Jh'] ['7d', '2d']
# 0.09342272099999999
# two pair 31302140000
# ['2c', 'Ah', '8s', 'Kc', 'Kd'] ['6c', '2h']
# 0.6600000000000001
# two pair 31003140000
# ['Td', 'Ah', '3s', 'Th', '3c'] ['9d', '4s']
# 0.6600000000000001
# nothing 11311080704
# ['2h', '7c', 'Kd', 'Jd', '8d'] ['3c', '4c']
# -0.20066757887999997
# one pair 20513100800
# ['8h', '7s', '5s', 'Tc', 'Kd'] ['5d', '4c']
# 0.07539302400000003
# one pair 21114120900
# ['Jc', '7s', '9c', 'Jd', 'Ah'] ['6c', 'Qh']
# 0.09342362700000001
# two pair 31302110000
# ['8h', '5h', 'Kh', 'Ks', '2s'] ['2h', 'Js']
# 0.6600000000000001
# one pair 20612100800
# ['3d', '2h', 'Qs', '6c', '8h'] ['6h', 'Td']
# 0.078363024
# nothing 11411090807
# ['8d', '4s', 'As', '7d', 'Jd'] ['9h', '3h']
# -0.19766727578999999
# three card 41413100000
# ['Ad', 'Ac', '3c', 'Ks', '2d'] ['As', 'Td']
# 0.96
# two pair 31009130000
# ['Kd', '9c', 'Ts', '3d', '8c'] ['Th', '9d']
# 0.6600000000000001
# two pair 30804140000
# ['4s', 'Ac', 'Kc', '8c', '8h'] ['4c', '5d']
# 0.6600000000000001
# nothing 11311090604
# ['3s', '9s', '4d', 'Kd', 'Jh'] ['2h', '6s']
# -0.20066728188
# one pair 21409080700
# ['Ad', 'Ah', '2h', '9s', '7d'] ['6h', '8c']
# 0.102272421
# one pair 20711100800
# ['8s', '2d', '5d', 'Jd', '7c'] ['7d', 'Th']
# 0.08133302400000006
# two pair 31202130000
# ['9s', 'Qc', '4d', 'Qd', 'Ks'] ['2s', '2c']
# 0.6600000000000001
# one pair 21011080700
# ['4h', 'Jd', '3c', 'Td', '7c'] ['Th', '8h']
# 0.09033242100000005
# one pair 20214120600
# ['2h', '5s', '4d', 'Qd', '2c'] ['6d', 'Ad']
# 0.06642361799999999
# one pair 21214110800
# ['Ad', 'Jh', 'Qc', '3d', '4h'] ['8h', 'Qh']
# 0.096423324
# nothing 11310090604
# ['3s', '4d', '6c', '2s', '9d'] ['Th', 'Kd']
# -0.20069728187999997
# two pair 31005140000
# ['8s', 'Th', 'Tc', '5c', '5s'] ['7h', 'As']
# 0.6600000000000001
# one pair 20212110800
# ['3h', '4h', '8s', 'Qs', '2d'] ['Js', '2s']
# 0.066363324
# one pair 21413120800
# ['Qs', '8d', '4s', 'Ah', 'Ac'] ['7d', 'Ks']
# 0.10239362399999999
# one pair 21412100900
# ['Td', '2c', '4s', 'Ah', 'Qd'] ['Ad', '9c']
# 0.10236302700000002
# one pair 20314121000
# ['3c', '3s', '7s', 'As', 'Qd'] ['Ts', '8c']
# 0.06942362999999999
# two pair 31307090000
# ['7d', 'Ks', '6h', '9h', 'Kd'] ['7c', '8d']
# 0.6600000000000001
# one pair 21310080600
# ['Kh', '5c', 'Ks', '6d', '3h'] ['Td', '8d']
# 0.09930241800000003
# one pair 21114080700
# ['Ac', '3c', 'Js', 'Jh', '8d'] ['5h', '7c']
# 0.09342242100000006
# three card 41113120000
# ['Tc', 'Jd', 'Js', 'Kc', 'Jc'] ['Qh', '2c']
# 0.96
# one pair 20211070600
# ['Jh', '5s', '2d', '2h', '7d'] ['4c', '6d']
# 0.06633211800000002
# two pair 30807130000
# ['8c', 'Kc', '7d', '8h', '9d'] ['7h', '5d']
# 0.6600000000000001
# two pair 31110090000
# ['Tc', '9s', 'Jd', 'Th', 'Jh'] ['7s', '3c']
# 0.6600000000000001
# one pair 20912080600
# ['5d', '9d', '6c', '8h', '9h'] ['4h', 'Qd']
# 0.087362418
# two pair 31206050000
# ['5h', 'Qc', 'Qh', '6c', '3d'] ['6d', '2c']
# 0.6600000000000001
# nothing 11312090804
# ['2d', '3d', '8s', '9s', '4c'] ['Ks', 'Qd']
# -0.20063727588
# nothing 11110080605
# ['Ts', '6d', 'Js', '5d', '2s'] ['8h', '4s']
# -0.20669758184999998
# nothing 11413111009
# ['Tc', 'Jc', 'Kc', 'Ad', '6d'] ['9s', '5s']
# -0.19760666972999996
# two pair 31208140000
# ['Qs', '7c', 'Qh', '6d', 'Ac'] ['8h', '8s']
# 0.6600000000000001
# one pair 20614121100
# ['Qc', 'Ts', '4h', 'Jd', '6h'] ['6s', 'Ac']
# 0.07842363299999999
# one pair 21211090500
# ['5s', '4d', 'Jd', '9c', '3h'] ['Qc', 'Qh']
# 0.09633271499999999
# two pair 30503120000
# ['Qh', '3s', '3d', 'Jc', 'Th'] ['5h', '5s']
# 0.6600000000000001
# one pair 21012110900
# ['Tc', 'Jc', 'Qd', '9c', '5s'] ['7c', 'Td']
# 0.09036332700000002
# one pair 20314120700
# ['5c', '3d', 'Qc', '3h', '7d'] ['2d', 'Ad']
# 0.06942362099999999
# one pair 21013120800
# ['6h', '5c', 'Kc', '8c', 'Td'] ['Qh', 'Ts']
# 0.09039362400000006
# flush 61312110602
# ['6c', 'Kc', 'Jc', '3h', '9d'] ['Qc', '2c']
# 0.96
# nothing 11412111006
# ['Ad', '3h', '6c', 'Qh', '2h'] ['Ts', 'Jc']
# -0.19763666981999997
# nothing 11412110604
# ['Qs', '2d', '4s', '6c', 'Ac'] ['3h', 'Jc']
# -0.19763668187999997
# two pair 31307120000
# ['Qs', '7d', '7c', 'Th', 'Kd'] ['Js', 'Ks']
# 0.6600000000000001
# one pair 21411060500
# ['Ad', '6c', '5h', 'Jh', '4s'] ['As', '3h']
# 0.10233181500000005
# one pair 21213100600
# ['Qh', 'Qd', '6s', '2d', '5s'] ['Kh', 'Ts']
# 0.09639301800000005
# full house 71305000000
# ['Ks', '5c', 'Kc', '3s', '5s'] ['3d', 'Kd']
# 0.96
# two pair 31412050000
# ['Ac', 'Qs', '5d', '2c', '4h'] ['Qd', 'Ad']
# 0.6600000000000001
# two pair 31008130000
# ['Kc', '8c', '6h', '8h', 'Tc'] ['4s', 'Ts']
# 0.6600000000000001
# two pair 31303110000
# ['3s', '3h', 'Kh', 'Js', '2d'] ['Ks', '4c']
# 0.6600000000000001
# one pair 20514090800
# ['5s', '8d', 'Ad', '5c', '3d'] ['6c', '9c']
# 0.07542272400000005
# two pair 30503120000
# ['6c', '3c', '7h', 'Qd', '3d'] ['5d', '5h']
# 0.6600000000000001
# one pair 21311090800
# ['Kh', 'Kc', '3c', 'Jd', '6d'] ['9h', '8s']
# 0.09933272399999998
# full house 70506000000
# ['5c', 'Jd', '8h', '6c', '5d'] ['6d', '5s']
# 0.96
# one pair 20312090800
# ['9s', 'Qh', '3d', '3h', '8h'] ['2c', '5s']
# 0.06936272399999999
# three card 41311090000
# ['Jc', '6h', '9s', 'Ks', '8s'] ['Kc', 'Kd']
# 0.96
# one pair 20613110700
# ['Jc', 'Kd', '6s', '6d', '7c'] ['4d', '5s']
# 0.07839332100000004
# one pair 21411090600
# ['6c', 'Ac', '9s', 'Jc', '2c'] ['Ah', '4h']
# 0.10233271799999999
# full house 70412000000
# ['Qs', 'Jh', 'Ad', '4s', '4d'] ['Qc', '4c']
# 0.96
# one pair 20814131200
# ['Kc', 'Qd', '8c', '4s', '8s'] ['Ts', 'Ad']
# 0.084423936
# two pair 31312100000
# ['Ts', '9h', 'Kh', 'Ks', '5h'] ['Qd', 'Qc']
# 0.6600000000000001
# one pair 20714131200
# ['Qc', '7d', '7c', 'Kh', '2h'] ['8c', 'Ah']
# 0.081423936
# one pair 21310090700
# ['7c', '3s', 'Td', '5h', 'Kc'] ['9c', 'Ks']
# 0.09930272100000004
# nothing 11311100906
# ['Th', 'Ks', '6d', '9c', '4d'] ['3h', 'Js']
# -0.20066697281999996
# nothing 11410090804
# ['Ad', '4d', '3c', 'Td', '9c'] ['8c', '2c']
# -0.19769727587999997
# two pair 31103070000
# ['Jd', '3h', '2s', 'Jh', '4s'] ['7s', '3c']
# 0.6600000000000001
# nothing 11412090706
# ['Qc', '6d', '9h', '7h', '4h'] ['5c', 'As']
# -0.19763727881999998
# two pair 31204070000
# ['6c', '7d', '4h', 'Qs', '5d'] ['4d', 'Qh']
# 0.6600000000000001
# two pair 31203130000
# ['3h', 'Kh', 'Jd', '6d', '3d'] ['Qc', 'Qd']
# 0.6600000000000001
# one pair 21013120900
# ['Kc', '6d', '7d', 'Td', 'Ts'] ['9h', 'Qh']
# 0.09039362700000006
# one pair 20611080500
# ['4h', '3d', 'Jh', '8h', '6d'] ['5s', '6h']
# 0.07833241500000004
# one pair 21013121100
# ['3d', 'Ts', '8h', 'Jc', 'Kh'] ['Qc', 'Td']
# 0.09039363300000006
# one pair 21214130700
# ['Qd', 'Kc', 'Qs', '5s', 'Ac'] ['6d', '7s']
# 0.09642392100000002
# one pair 21014090700
# ['Tc', 'As', '9c', '7h', '4c'] ['Ts', '5h']
# 0.09042272099999998
# one pair 20312080500
# ['5h', '3c', '8d', '2c', '4h'] ['Qs', '3d']
# 0.06936241499999998
# two pair 30906140000
# ['3h', '6h', '6d', '4h', '9d'] ['9s', 'As']
# 0.6600000000000001
# two pair 30703110000
# ['2d', '7s', '3d', '7d', '3c'] ['Jc', '4d']
# 0.6600000000000001
# nothing 11312080706
# ['7s', '3s', 'Qs', 'Kd', '4h'] ['8h', '6c']
# -0.20063757882
# one pair 21213080600
# ['8s', '4h', 'Qd', 'Kc', '6d'] ['5h', 'Qh']
# 0.09639241800000004
# nothing 11412110706
# ['Jc', '6d', 'Ad', 'Qh', '3c'] ['5c', '7c']
# -0.19763667881999997
# two pair 30805110000
# ['Jh', '2d', '8c', '5h', '8d'] ['7h', '5d']
# 0.6600000000000001
# one pair 20214100900
# ['Ac', '5s', 'Th', '9h', '8s'] ['2c', '2h']
# 0.06642302700000005
# nothing 11413120804
# ['3c', 'As', 'Kh', 'Qc', '2s'] ['8c', '4d']
# -0.19760637587999996
# nothing 11312111006
# ['2d', 'Tc', 'Kh', 'Jh', '4d'] ['Qc', '6h']
# -0.20063666981999997
# three card 40714100000
# ['7s', 'Ad', '8s', '7h', 'Tc'] ['9c', '7d']
# 0.96
# flush 61211100706
# ['Js', '7s', '5d', '6c', 'Ts'] ['Qs', '6s']
# 0.96
# two pair 31312110000
# ['Td', 'Kh', 'Jc', 'Qs', 'Qd'] ['6c', 'Kc']
# 0.6600000000000001
# one pair 20614131000
# ['As', 'Td', '3d', 'Kh', '2c'] ['6s', '6h']
# 0.07842393
# one pair 21014121100
# ['Td', '2d', 'Qd', 'Jh', '7d'] ['Th', 'Ac']
# 0.090423633
# nothing 11211100807
# ['Ts', '7c', '8d', '6c', 'Js'] ['Qs', '2h']
# -0.20366697578999998
# two pair 31003130000
# ['3s', '2s', '8s', 'Kd', '3c'] ['Ts', 'Tc']
# 0.6600000000000001
# one pair 20614131000
# ['Ah', '8d', 'Td', '6s', '6d'] ['2d', 'Kc']
# 0.07842393
# three card 40513090000
# ['5h', '6c', '5d', '2s', '5s'] ['Ks', '9s']
# 0.96
# one pair 21113120900
# ['9s', '4c', '5h', 'Qs', 'Jc'] ['Kc', 'Jd']
# 0.09339362699999998
# nothing 11209080706
# ['7d', '3c', '6s', 'Qs', '4h'] ['9h', '8s']
# -0.20372757881999998
# one pair 20211100700
# ['2h', 'Td', '3s', '4s', '7s'] ['Jh', '2c']
# 0.06633302100000005
# one pair 21013121100
# ['Tc', 'Js', 'Th', 'Kc', '2d'] ['Qh', '6s']
# 0.09039363300000006
# one pair 21412100800
# ['8s', 'Qs', 'Ad', 'Ah', '6c'] ['Ts', '5c']
# 0.10236302400000002
# one pair 20912080600
# ['6c', '9h', 'Qc', '8s', '9d'] ['2c', '5d']
# 0.087362418
# one pair 20511090800
# ['Jh', '9h', '2c', '8d', '5d'] ['5c', '4s']
# 0.07533272400000005
# two pair 31406090000
# ['As', '6c', '8s', '6s', '5c'] ['9s', 'Ah']
# 0.6600000000000001
# one pair 21213100700
# ['4d', '3d', 'Qs', 'Ks', 'Qh'] ['7h', 'Th']
# 0.09639302100000005
# nothing 11311090805
# ['8h', 'Kh', '9h', '2c', 'Jd'] ['3h', '5d']
# -0.20066727585
# one pair 21211090700
# ['Qc', '4h', 'Jc', 'Qs', '7d'] ['9d', '5c']
# 0.09633272099999998
# one pair 21113100800
# ['Tc', 'Kd', '8h', 'Jd', '5s'] ['Jc', '2h']
# 0.09339302400000005
# straight 51110090807
# ['Td', '6s', 'Jd', '9d', '6c'] ['7d', '8c']
# 0.96
# two pair 31003130000
# ['Jd', 'Ts', 'Th', '3d', '7d'] ['3h', 'Kc']
# 0.6600000000000001
# two pair 31206100000
# ['Qd', '6h', '7s', 'Th', 'Qc'] ['6c', '4h']
# 0.6600000000000001
# one pair 20914131000
# ['Ah', '9d', '3c', '9c', 'Kc'] ['6h', 'Ts']
# 0.08742393000000001
# one pair 20514110600
# ['3c', '6d', 'As', '5c', '5d'] ['Jh', '4d']
# 0.07542331799999999
# two pair 31404130000
# ['Kd', 'Ac', 'Ad', '3h', '6d'] ['4d', '4c']
# 0.6600000000000001
# nothing 11310080705
# ['Tc', '3h', '8d', '4d', '5c'] ['7s', 'Kh']
# -0.20069757884999997
# flush 61412090807
# ['7h', 'Qs', 'Ah', 'Qh', '9h'] ['8h', '4c']
# 0.96
# one pair 20614120800
# ['Qc', '6h', 'Ad', '6c', '8h'] ['5c', '2h']
# 0.078423624
# full house 70612000000
# ['6d', '6c', 'Qs', 'Tc', '5s'] ['6h', 'Qd']
# 0.96
# one pair 20812110900
# ['9d', 'Qs', 'Jc', '8s', '8c'] ['5c', '7c']
# 0.08436332700000002
# one pair 20314100600
# ['Ah', 'Th', '2d', '6d', '3h'] ['3c', '4h']
# 0.06942301800000006
# straight 51211100908
# ['Js', 'Qc', '9h', 'Qs', '8s'] ['6h', 'Td']
# 0.96
# one pair 20412100900
# ['6d', 'Td', '9c', '2s', '4h'] ['Qc', '4c']
# 0.072363027
# straight 51211100908
# ['Th', '5d', 'Js', 'Tc', '8c'] ['9d', 'Qh']
# 0.96
# one pair 21314100900
# ['Kd', '2d', 'Ks', '9d', 'Th'] ['5h', 'Ac']
# 0.099423027
# full house 70302000000
# ['8s', '2d', '3h', '3c', '3d'] ['2s', '7s']
# 0.96
# one pair 21013120900
# ['Qh', 'Kc', '9c', '4c', 'Ts'] ['8c', 'Td']
# 0.09039362700000006
# one pair 21014131100
# ['Kc', 'As', '4s', 'Th', 'Jc'] ['Ts', '2d']
# 0.09042393300000001
# nothing 11310070604
# ['2d', '7h', 'Kc', '4s', 'Ts'] ['6s', '3s']
# -0.20069788187999998
# two pair 31002130000
# ['Kd', '2h', 'Jh', 'Ts', '2s'] ['5s', 'Td']
# 0.6600000000000001
# nothing 11312110904
# ['Js', 'Kd', '4s', 'Qc', '2d'] ['3s', '9h']
# -0.20063667287999998
# two pair 31002090000
# ['Ts', '9d', '2c', '6s', 'Th'] ['2s', '3d']
# 0.6600000000000001
# nothing 11413120807
# ['Kd', 'As', '3c', '7h', '8c'] ['6s', 'Qd']
# -0.19760637578999996
# one pair 20213100900
# ['9c', '7c', 'Ks', 'Td', '2c'] ['2h', '5d']
# 0.06639302700000002
# one pair 21213090700
# ['7h', 'Kd', '6d', 'Qs', '5h'] ['Qh', '9d']
# 0.09639272100000004
# one pair 21312090500
# ['5d', '4s', '9c', 'Qs', 'Ks'] ['Kd', '2h']
# 0.09936271500000002
# two pair 31005120000
# ['Qh', '5d', 'Th', 'Td', '2d'] ['5s', '9c']
# 0.6600000000000001
# straight 51312111009
# ['4s', '9d', 'Kh', 'Qc', 'Jd'] ['5d', 'Th']
# 0.96
# one pair 20514100800
# ['5c', '6h', 'As', 'Td', '3d'] ['5h', '8c']
# 0.07542302400000006
# nothing 11211070504
# ['4c', 'Jh', '3c', '2c', '5d'] ['7s', 'Qd']
# -0.20366788487999998
# flush 61413090504
# ['9h', 'Kh', 'Ts', '5h', '4h'] ['5d', 'Ah']
# 0.96
# two pair 30803090000
# ['3h', '9s', '4d', '8c', '8d'] ['3s', '2c']
# 0.6600000000000001
# flush 61312050302
# ['Ah', '2s', 'Qs', 'Ac', '5s'] ['3s', 'Ks']
# 0.96
# two pair 30802140000
# ['8h', '9h', 'Ad', '8d', '2c'] ['Jd', '2s']
# 0.6600000000000001
# one pair 21009080700
# ['4d', '7h', '8s', '9s', 'Tc'] ['Ts', '5c']
# 0.09027242099999999
# one pair 21314090400
# ['2s', '3c', 'Kc', 'Kh', '9s'] ['4d', 'Ah']
# 0.099422712
# one pair 20314131100
# ['Jh', 'Tc', '2s', '3d', 'Ac'] ['Ks', '3s']
# 0.069423933
# one pair 21110090700
# ['9s', '5c', '6d', '7c', 'Js'] ['Td', 'Jh']
# 0.09330272100000003
# nothing 11412110605
# ['6h', '4c', '5s', 'Qs', 'As'] ['3d', 'Jc']
# -0.19763668184999997
# one pair 21013110400
# ['Kh', '4s', 'Ts', 'Js', 'Td'] ['2s', '3d']
# 0.09039331200000006
# one pair 20710080500
# ['4d', '5s', '2s', 'Tc', '7h'] ['7s', '8h']
# 0.08130241500000002
# one pair 21411100700
# ['Td', 'Ad', '7h', '6d', 'Js'] ['4c', 'Ah']
# 0.102333021
# one pair 21213090800
# ['6c', 'Qc', '8d', '9c', 'Ks'] ['5h', 'Qh']
# 0.09639272400000004
# one pair 20913100800
# ['9c', '9s', '2d', 'Ks', 'Tc'] ['6s', '8s']
# 0.08739302400000004
# one pair 20314121000
# ['4c', '8c', 'Tc', '3d', 'Qd'] ['3s', 'Ad']
# 0.06942362999999999
# one pair 20812111000
# ['3c', 'Jc', '8c', 'Td', 'Qc'] ['7h', '8d']
# 0.08436333000000001
# nothing 11310090806
# ['6h', '3c', 'Th', '4s', '9c'] ['8h', 'Kd']
# -0.20069727581999997
# one pair 21014070600
# ['6c', 'Th', '4c', 'Ad', '2d'] ['Td', '7d']
# 0.09042211800000005
# two pair 30906130000
# ['Ts', '7s', '6d', 'Kc', '9c'] ['9d', '6h']
# 0.6600000000000001
# one pair 20713080600
# ['2d', 'Kd', '7h', '7d', '5s'] ['8c', '6d']
# 0.08139241800000002
# one pair 21314121100
# ['5s', 'Qd', '6s', 'Jd', 'Ad'] ['Kd', 'Kh']
# 0.09942363300000001
# nothing 11413121008
# ['Tc', '8c', 'Qd', 'Ac', 'Ks'] ['7d', '5c']
# -0.19760636975999996
# two pair 31210140000
# ['8d', 'Td', 'Qd', 'As', 'Th'] ['Kc', 'Qs']
# ...
# two pair 31205140000
# ['Qs', '9s', '5c', 'Ad', 'Qd'] ['8c', '5h']
# 0.6600000000000001
# one pair 21109070600
# ['9d', 'Jh', 'Js', '4d', '6d'] ['7h', '5h']
# 0.09327211799999999
# one pair 20911070500
# ['9c', '3h', '9d', '5h', 'Js'] ['2d', '7d']
# 0.08733211500000004
# two pair 31009140000
# ['Tc', '9c', '3d', '9d', 'Ah'] ['2c', 'Th']
# 0.6600000000000001
# two pair 31002140000
# ['Ts', 'Tc', '2c', '2h', 'Jd'] ['Ah', '5s']
# 0.6600000000000001
# two pair 31105140000
# ['3h', 'Ac', 'Js', '8c', '5d'] ['Jc', '5c']
# 0.6600000000000001
# one pair 21013080700
# ['Ts', '6h', '2s', 'Kc', '8d'] ['7h', 'Td']
# 0.09039242100000003
# nothing 11211090807
# ['7s', 'Js', '4h', '8h', '9d'] ['3d', 'Qd']
# -0.20366727579
# nothing 11411100907
# ['2c', 'As', '9d', '7d', '3d'] ['Ts', 'Jh']
# -0.19766697278999995
# two pair 31307120000
# ['3h', '7s', 'Ks', 'Qc', '8s'] ['7d', 'Kc']
# 0.6600000000000001
# one pair 21213110900
# ['Ks', '2d', '8s', 'Qc', '9h'] ['Qd', 'Js']
# 0.09639332700000006
# nothing 11211100805
# ['8s', 'Th', 'Qd', 'Jh', '2d'] ['3c', '5h']
# -0.20366697585
# one pair 20712111000
# ['Jh', '9d', 'Qd', 'Ts', '3c'] ['7d', '7h']
# 0.08136333000000001
# one pair 20714121100
# ['Ah', '7c', '6c', 'Jh', 'Qc'] ['4h', '7d']
# 0.081423633
# one pair 21210090800
# ['8c', 'Qd', 'Qc', '6h', '2d'] ['Ts', '9c']
# 0.09630272400000003
# flush 61410090704
# ['As', '4s', 'Ts', '3h', '9s'] ['7h', '7s']
# 0.96
# two pair 30704140000
# ['4s', '7h', 'Ad', '2s', '4c'] ['7s', '3d']
# 0.6600000000000001
# one pair 21213110800
# ['Ks', 'Qc', '2c', '4h', 'Jd'] ['8s', 'Qh']
# 0.09639332400000006
# flush 61310090403
# ['Kc', 'Tc', '5d', '4c', '7h'] ['9c', '3c']
# 0.96
# two pair 31106130000
# ['Jc', '7d', '6h', 'Jd', '6d'] ['Kd', '3s']
# 0.6600000000000001
# nothing 11311100907
# ['Kh', '3d', '7s', '9d', 'Th'] ['2c', 'Jh']
# -0.20066697278999995
# one pair 21014120800
# ['Ad', 'Qs', 'Tc', '8h', '6c'] ['7c', 'Ts']
# 0.09042362400000001
# two pair 30403120000
# ['3c', '6d', '3s', 'Qc', '2h'] ['4h', '4d']
# 0.6600000000000001
# full house 71110000000
# ['Ac', 'Jc', 'Ts', 'Js', 'Jh'] ['Td', '3s']
# 0.96
# one pair 21014110900
# ['5s', 'Tc', '9c', '3s', 'Jd'] ['Ah', 'Td']
# 0.090423327
# nothing 11411090605
# ['4d', 'Jc', 'As', '9c', '2d'] ['6d', '5h']
# -0.19766728185
# nothing 11411100604
# ['4s', 'Td', '6c', 'Jc', '3d'] ['Ad', '2d']
# -0.19766698187999998
# one pair 21114130800
# ['Kd', '4s', '8h', '6c', 'Jh'] ['As', 'Jc']
# 0.09342392400000002
# one pair 20911060500
# ['4d', 'Js', '9s', '6d', '2d'] ['9c', '5d']
# 0.08733181500000003
# straight 50908070605
# ['7h', '6h', 'Ad', '8h', '3d'] ['9h', '5d']
# 0.96
# flush 61109070503
# ['Jc', 'Qh', '3c', 'Ks', '7c'] ['5c', '9c']
# 0.96
# one pair 21110090700
# ['7d', '9c', '3d', 'Td', 'Jh'] ['Jc', '6s']
# 0.09330272100000003
# one pair 20413100900
# ['4c', '4h', '3c', '5d', '9d'] ['Ks', 'Th']
# 0.07239302700000003
# one pair 20814100700
# ['8d', '7c', '5h', 'Ac', '8c'] ['Ts', '2s']
# 0.08442302099999999
# one pair 20514121000
# ['5h', 'Qc', '5c', 'Ac', 'Ts'] ['2h', '9h']
# 0.07542362999999999
# two pair 31102130000
# ['2h', 'Js', 'Jh', '3c', '2s'] ['9h', 'Kc']
# 0.6600000000000001
# two pair 31307050000
# ['7c', '5c', '7d', 'Ks', '3c'] ['3s', 'Kc']
# 0.6600000000000001
# flush 61413121007
# ['Td', '7d', 'Kd', '5d', 'Qd'] ['4c', 'Ad']
# 0.96
# two pair 31003140000
# ['Ts', 'Td', '6c', '3c', '8c'] ['3h', 'Ac']
# 0.6600000000000001
# two pair 31207140000
# ['7c', 'Qs', '7d', 'Ad', 'Qd'] ['3d', 'Kc']
# 0.6600000000000001
# two pair 30903120000
# ['3s', '4h', '3c', '9s', 'Qc'] ['8d', '9h']
# 0.6600000000000001
# full house 71009000000
# ['Td', 'Th', '7h', '4c', 'Tc'] ['9c', '9h']
# 0.96
# one pair 20714090500
# ['5s', '9h', '7c', '7h', '3c'] ['2d', 'Ah']
# 0.08142271499999998
# nothing 11412110807
# ['Ad', '7d', 'Qd', '8s', 'Jc'] ['2c', '4s']
# -0.19763667578999997
# two pair 31410090000
# ['Th', 'Ad', '4d', '2h', '9c'] ['Ac', 'Td']
# 0.6600000000000001
# one pair 20914080700
# ['8c', 'Ah', '7c', '9d', '5h'] ['2h', '9c']
# 0.08742242100000006
# two pair 30805110000
# ['8s', '5d', '5h', '6s', '3s'] ['8c', 'Jc']
# 0.6600000000000001
# two pair 31307100000
# ['7d', '7c', 'Tc', '5d', 'Ks'] ['2h', 'Kc']
# 0.6600000000000001
# one pair 21314100800
# ['Kh', '4d', 'Kd', 'As', 'Tc'] ['8s', '7c']
# 0.099423024
# one pair 20812070600
# ['7d', '8h', 'Qs', '3c', '2h'] ['8c', '6s']
# 0.08436211799999999
# straight 51405040302
# ['2s', '7s', '5c', '3h', '3c'] ['Ah', '4h']
# 0.96
# straight 51009080706
# ['Th', '9h', '6s', '8s', 'Ks'] ['7s', '2h']
# 0.96
# one pair 20612111000
# ['6s', '7h', 'Tc', 'Js', '8h'] ['6d', 'Qh']
# 0.07836333000000001
# one pair 20408070500
# ['8d', '3h', '2h', '4c', '7c'] ['4d', '5d']
# 0.07224211500000002
# three card 41413080000
# ['Ac', 'Kh', '8d', 'Ah', '4h'] ['7c', 'As']
# 0.96
# nothing 11310070605
# ['Kh', 'Th', '7d', '2h', '3d'] ['6h', '5c']
# -0.20069788184999998
# straight 51211100908
# ['Jh', 'Th', '9c', '8c', 'Tc'] ['Qs', '8h']
# 0.96
# one pair 21214131000
# ['Qd', 'Kc', '5c', 'Qs', 'Th'] ['Ad', '8s']
# 0.09642393000000002
# two pair 31405120000
# ['Qh', '5d', '5s', '2h', 'Ad'] ['9h', 'Ah']
# 0.6600000000000001
# two pair 31108060000
# ['8h', '4d', '6d', '5h', 'Jh'] ['8s', 'Js']
# 0.6600000000000001
# three card 41012040000
# ['3d', '2h', 'Td', 'Qh', 'Ts'] ['4s', 'Tc']
# 0.96
# one pair 21411080700
# ['2c', '8d', 'Ah', 'Ad', 'Jc'] ['7d', '5c']
# 0.10233242099999998
# three card 41112090000
# ['Jh', '4c', 'Jc', '9s', 'Qd'] ['3d', 'Js']
# 0.96
# three card 40614100000
# ['Ad', '6h', '2c', '6s', '9d'] ['6d', 'Tc']
# 0.96
# two pair 30903110000
# ['7d', '9h', 'Jd', '3s', '3c'] ['9d', '5d']
# 0.6600000000000001
# one pair 20911050400
# ['4d', '3h', 'Jc', '9d', '2h'] ['9s', '5d']
# 0.08733151200000003
# one pair 21314111000
# ['3c', 'Ts', 'Jd', 'Kh', 'Ah'] ['Kc', '4c']
# 0.09942333
# one pair 20713121000
# ['2d', '3h', 'Kh', '7d', 'Tc'] ['Qh', '7s']
# 0.08139363000000005
# nothing 11413100705
# ['7s', 'As', 'Td', '3s', '2s'] ['Kd', '5h']
# -0.19760697885
# flush 61413110807
# ['Ks', '8s', 'Js', '3s', '7s'] ['As', 'Kh']
# 0.96
# two pair 30605040000
# ['6c', '3s', '4c', '6s', '5h'] ['5d', '4d']
# 0.6600000000000001
# nothing 11411090807
# ['Ad', '8d', '6d', '7h', '9s'] ['Jd', '3s']
# -0.19766727578999999
# three card 40513060000
# ['2d', '4c', 'Kh', '6d', '5s'] ['5d', '5h']
# 0.96
# flush 61412100704
# ['5d', '7h', '5s', 'Th', '4h'] ['Ah', 'Qh']
# 0.96
# one pair 20313120900
# ['3c', '3d', 'Qd', 'Ks', '6c'] ['9c', '2s']
# 0.06939362700000004
# nothing 11411100706
# ['Ad', 'Th', '5c', '7h', 'Js'] ['3s', '6d']
# -0.19766697881999995
# straight 50706050403
# ['5c', '4d', '6h', 'Qc', '3h'] ['5d', '7c']
# 0.96
# one pair 20214110900
# ['Jc', '2s', '9d', '7d', '8d'] ['Ah', '2h']
# 0.06642332700000006
# one pair 21014130900
# ['9s', 'Td', '7d', 'Ad', '3d'] ['Ks', 'Tc']
# 0.09042392700000002
# one pair 20613080500
# ['6h', 'Kh', '4s', '6d', '3h'] ['5c', '8c']
# 0.07839241500000002
# one pair 21413120800
# ['Kc', '4d', '5s', 'Qc', 'As'] ['8s', 'Ah']
# 0.10239362399999999
# nothing 11312111008
# ['Qd', 'Kc', 'Jh', '8c', '2s'] ['6c', 'Tc']
# -0.20063666975999997
# nothing 11411100907
# ['Ts', '5s', '7c', '9h', '6s'] ['Ad', 'Jd']
# -0.19766697278999995
# one pair 20611080400
# ['6d', '2d', 'Jh', '3c', '6h'] ['4d', '8h']
# 0.07833241200000005
# one pair 20814131200
# ['Ah', 'Kc', 'Qd', '8h', '9d'] ['8s', '2c']
# 0.084423936
# straight 50807060504
# ['8s', '8c', '6c', '5c', '4c'] ['7d', 'Ts']
# 0.96
# two pair 31302090000
# ['6d', '8s', 'Kh', 'Ks', '9d'] ['2s', '2h']
# 0.6600000000000001
# two pair 30802110000
# ['2s', '9d', 'Jh', '2d', 'Tc'] ['8d', '8h']
# 0.6600000000000001
# one pair 21214110600
# ['Jh', '3d', 'Ah', '4d', '6d'] ['Qc', 'Qh']
# 0.09642331800000001
# nothing 11312100904
# ['Kc', '2s', 'Qd', 'Tc', '4s'] ['3s', '9d']
# -0.20063697288
# two pair 31403100000
# ['6h', '3s', '5d', 'Ah', 'Ac'] ['Ts', '3d']
# 0.6600000000000001
# one pair 20313120900
# ['Qd', 'Kc', '8s', '5c', '3s'] ['3d', '9d']
# 0.06939362700000004
# one pair 20514121000
# ['5c', '2s', '6s', 'Qc', '5d'] ['Td', 'Ac']
# 0.07542362999999999
# one pair 20511080700
# ['5c', '6c', 'Jh', '5h', '2h'] ['8d', '7d']
# 0.07533242100000004
# one pair 21113090600
# ['9d', 'Ks', '4h', '6h', 'Jh'] ['2s', 'Js']
# 0.09339271800000004
# two pair 31105120000
# ['5s', '6s', '4h', 'Qd', 'Js'] ['5d', 'Jd']
# 0.6600000000000001
# one pair 20414120700
# ['2h', 'As', '6h', 'Qs', '4h'] ['4s', '7s']
# 0.072423621
# straight 50605040302
# ['4c', '9h', '3s', '2s', '6d'] ['5s', '3d']
# 0.96
# one pair 20714110600
# ['2d', '3c', 'Jh', '7c', '6c'] ['7s', 'As']
# 0.081423318
# three card 41406050000
# ['Ac', 'As', 'Ad', '6c', '4c'] ['5s', '2h']
# 0.96
# flush 61306050302
# ['6s', '2s', '3s', 'Kc', 'Ks'] ['3c', '5s']
# 0.96
# one pair 20814110900
# ['8c', '5h', 'Ac', '8s', '9s'] ['Jc', '2d']
# 0.08442332699999999
# two pair 30402120000
# ['4s', '6c', '2d', '2h', '3s'] ['Qc', '4c']
# 0.6600000000000001
# three card 41213090000
# ['9d', 'Kh', 'Qd', 'Qh', 'Qc'] ['3h', '7s']
# 0.96
# nothing 11413090807
# ['Ah', 'Kc', '7c', '4d', '2s'] ['9d', '8c']
# -0.19760727578999998
# nothing 11210090705
# ['Ts', '9s', 'Qc', '2d', '4s'] ['7d', '5d']
# -0.20369727884999997
# two pair 31312090000
# ['4h', 'Qd', 'Kc', '8h', 'Qs'] ['Ks', '9d']
# 0.6600000000000001
# one pair 20414110900
# ['7c', 'Jc', '4s', '9h', '4d'] ['6c', 'As']
# 0.07242332699999998
# two pair 30602120000
# ['6s', 'Tc', 'Qd', '2s', '6c'] ['3s', '2h']
# 0.6600000000000001
# two pair 31410120000
# ['Th', 'As', 'Ah', 'Qs', '7h'] ['Tc', 'Js']
# 0.6600000000000001
# straight 50605040302
# ['3d', '2c', '5h', '9d', '6c'] ['5d', '4h']
# 0.96
# one pair 21214080500
# ['4c', 'Qh', 'Ad', '8d', '5s'] ['Qc', '2c']
# 0.09642241499999998
# two pair 31304140000
# ['4s', 'Ac', 'Js', 'Kd', '4h'] ['Kc', '8d']
# 0.6600000000000001
# three card 41412080000
# ['8h', '6c', 'Ad', '5d', 'As'] ['Ah', 'Qh']
# 0.96
# two pair 30805130000
# ['8h', 'Kh', '5s', 'Jc', 'Qd'] ['5c', '8d']
# 0.6600000000000001
# one pair 21014080700
# ['5s', 'Ah', 'Th', '8s', 'Ts'] ['4d', '7s']
# 0.09042242100000006
# three card 41014090000
# ['9s', 'Tc', '6d', 'Ah', 'Ts'] ['Th', '3h']
# 0.96
# two pair 30706140000
# ['5c', '8c', '7h', '6h', 'Ac'] ['7d', '6s']
# 0.6600000000000001
# one pair 20412080600
# ['6h', '8c', '5h', '3d', '4d'] ['Qd', '4h']
# 0.07236241799999998
# one pair 20214121000
# ['Qs', 'Ac', '5d', 'Tc', '9d'] ['2h', '2d']
# 0.06642362999999998
# nothing 11413111009
# ['Jc', '2s', '7d', 'Kc', 'Th'] ['Ad', '9s']
# -0.19760666972999996
# one pair 20610090400
# ['9h', 'Td', '6d', '3d', '2d'] ['4h', '6c']
# 0.07830271200000002
# flush 61007050403
# ['7s', '3h', 'Ks', '5h', '4h'] ['7h', 'Th']
# 0.96
# one pair 20414131200
# ['4s', 'Qh', 'Td', 'Ks', 'As'] ['2d', '4h']
# 0.072423936
# one pair 20912100700
# ['9h', '7d', 'Ts', '6h', '9s'] ['Qc', '5c']
# 0.08736302100000001
# nothing 11413121109
# ['9c', '2c', 'Jh', 'Kd', 'Qc'] ['Ad', '3d']
# -0.19760636672999998
# three card 40509080000
# ['9s', '2s', '5s', '8c', '5h'] ['5d', '4d']
# 0.96
# nothing 11311080504
# ['5h', 'Jh', 'Ks', '4c', '8s'] ['2h', '3d']
# -0.20066758487999997
# two pair 31407130000
# ['7d', '5s', 'As', 'Kc', '4c'] ['Ac', '7c']
# 0.6600000000000001
# three card 41113090000
# ['9c', 'Jh', 'Jd', '7c', '2s'] ['Js', 'Kd']
# 0.96
# three card 41314080000
# ['As', '3c', 'Kd', 'Kh', 'Ks'] ['8h', '5d']
# 0.96
# two pair 30906100000
# ['9s', 'Td', '3s', '6s', '7d'] ['9d', '6d']
# 0.6600000000000001
# one pair 20713100400
# ['4c', 'Ks', 'Tc', '7h', '7d'] ['2c', '3s']
# 0.08139301200000004
# two pair 31303120000
# ['Qh', 'Ks', '3d', 'Kd', '3c'] ['6d', '9s']
# 0.6600000000000001
# three card 40614120000
# ['3c', '6c', '6s', 'Qd', '6d'] ['7h', 'Ac']
# 0.96
# nothing 11310080706
# ['Kh', '8h', '4s', 'Tc', '7h'] ['3s', '6h']
# -0.20069757881999997
# one pair 20709060500
# ['7s', '3d', '5d', '7c', '9h'] ['6d', '2c']
# 0.08127181500000005
# nothing 11412090806
# ['9h', '4s', '6d', '5s', '8h'] ['Qc', 'Ac']
# -0.19763727581999999
# flush 61311050302
# ['6h', 'Jc', 'Kc', '3c', '5c'] ['2c', '2s']
# 0.96
# nothing 11413121109
# ['Jd', 'As', '2h', '9h', '7s'] ['Kc', 'Qh']
# -0.19760636672999998
# one pair 20814100900
# ['2s', 'Th', '8d', 'Ad', '8c'] ['9d', '6s']
# 0.08442302699999998
# one pair 21108060500
# ['5h', '6d', '3h', '8h', 'Jd'] ['Js', '4s']
# 0.09324181500000003
# nothing 11411100807
# ['8h', 'Ac', '5s', '3d', 'Tc'] ['7s', 'Jh']
# -0.19766697578999998
# flush 61310090302
# ['9h', '2h', 'Th', '3h', '6c'] ['Td', 'Kh']
# 0.96
# one pair 20713100900
# ['Kh', '9d', '7h', 'Td', '3s'] ['5h', '7c']
# 0.08139302700000003
# one pair 21408060500
# ['Ac', '6d', 'Ad', '8h', '5s'] ['4d', '3d']
# 0.10224181500000004
# one pair 20214100800
# ['As', '4d', '2d', 'Td', '2h'] ['6h', '8c']
# 0.06642302400000005
# nothing 11413121109
# ['Kd', 'Jh', '6s', '2c', '9d'] ['Ad', 'Qh']
# -0.19760636672999998
# one pair 21013121100
# ['Kc', 'Qd', 'Tc', '6s', 'Td'] ['Js', '2d']
# 0.09039363300000006
# straight 51009080706
# ['Ts', '7s', '3s', '8h', '6s'] ['4c', '9c']
# 0.96
# nothing 11312100705
# ['Tc', '3d', '5s', '7d', '4h'] ['Ks', 'Qh']
# -0.20063697884999998
# one pair 21014090800
# ['8c', 'As', '2d', '9s', '7c'] ['Th', 'Td']
# 0.09042272399999998
# two pair 30806110000
# ['8s', '3d', '8d', '6d', '3h'] ['Jc', '6c']
# 0.6600000000000001
# straight 51110090807
# ['9c', '5c', '7h', 'Jc', '3d'] ['Ts', '8s']
# 0.96
# nothing 11410090704
# ['2h', 'Ad', '4d', '7s', '3h'] ['9s', 'Tc']
# -0.19769727887999997
# one pair 20614100900
# ['6s', 'As', 'Td', '6d', '9s'] ['2s', '4c']
# 0.07842302699999998
# two pair 30902140000
# ['2c', '2d', 'As', '9d', '6h'] ['9c', '5s']
# 0.6600000000000001
# nothing 11413121008
# ['Ah', '2c', 'Td', '7s', 'Qc'] ['Kc', '8c']
# -0.19760636975999996
# one pair 21109080600
# ['8h', 'Jh', '3h', '4h', 'Js'] ['6d', '9c']
# 0.093272418
# nothing 11413110605
# ['4c', '5s', 'Kc', '3c', '6s'] ['Ah', 'Jd']
# -0.19760668184999997
# two pair 31205130000
# ['8s', 'Qd', 'Qh', '5h', 'Kc'] ['6d', '5c']
# 0.6600000000000001
# one pair 20314100800
# ['3d', 'Th', '3s', '7d', '5c'] ['8s', 'Ah']
# 0.06942302400000006
# one pair 21114130500
# ['Jc', 'Jh', '5c', 'Ah', '2s'] ['Kd', '4d']
# 0.09342391500000002
# one pair 21214080600
# ['Qs', '6c', '5h', 'Qh', 'Ah'] ['2c', '8h']
# 0.09642241799999998
# one pair 20314131100
# ['Kc', 'Jd', '5c', 'Ad', '3d'] ['3h', '9d']
# 0.069423933
# nothing 11311100905
# ['9c', 'Jc', '2c', '4s', 'Kd'] ['5h', 'Th']
# -0.20066697284999996
# one pair 21413121100
# ['Ac', 'Ks', '9d', 'Jd', 'Ah'] ['5h', 'Qc']
# 0.10239363299999998
# two pair 31108090000
# ['5c', 'Jh', '8c', '4h', 'Js'] ['9h', '8s']
# 0.6600000000000001
# one pair 20414121000
# ['2d', '4c', '8h', 'Qh', '4s'] ['Ts', 'Ah']
# 0.07242362999999999
# straight 50706050403
# ['4c', '6s', '7c', '3h', '5c'] ['2c', '9h']
# 0.96
# two pair 30705100000
# ['7s', '7h', '3d', '5h', '5s'] ['6d', 'Ts']
# 0.6600000000000001
# nothing 11410090604
# ['6h', '9c', '3h', '2d', 'Tc'] ['4d', 'Ah']
# -0.19769728187999996
# nothing 11211080504
# ['Qs', '2s', '5d', '4c', 'Jh'] ['8d', '3c']
# -0.20366758487999997
# one pair 20514100900
# ['Ts', '5s', '8s', '5h', '4d'] ['Ah', '9s']
# 0.07542302700000006
# two pair 31412090000
# ['5h', '9h', 'Ac', 'Qd', 'Ah'] ['3c', 'Qh']
# 0.6600000000000001
# nothing 11412110906
# ['9c', '2d', 'Ah', '6d', 'Qd'] ['Jc', '5c']
# -0.19763667281999997
# one pair 20813121100
# ['2c', '3c', 'Js', '8s', 'Kh'] ['Qc', '8c']
# 0.08439363300000005
# two pair 30604090000
# ['8h', '4c', '4d', '6c', '6s'] ['9h', '3h']
# 0.6600000000000001
# one pair 20211100900
# ['Tc', '9s', '5h', '7s', '2c'] ['Js', '2h']
# 0.06633302700000004
# flush 61009070603
# ['3c', '9c', 'Tc', '6c', '4s'] ['7c', '3d']
# 0.96
# two pair 31107100000
# ['Js', '8s', 'Th', 'Jh', '7h'] ['4d', '7d']
# 0.6600000000000001
# one pair 20412100800
# ['Td', 'Qd', '4s', '2d', '4c'] ['8s', '5h']
# 0.072363024
# two pair 30604130000
# ['6d', '4h', '6h', '4s', 'Qh'] ['Ts', 'Ks']
# 0.6600000000000001
# one pair 21411080700
# ['Ah', '7c', '4s', 'Jd', '8c'] ['As', '5d']
# 0.10233242099999998
# two pair 30403140000
# ['3h', '4h', '4d', '7h', '5d'] ['Ac', '3d']
# 0.6600000000000001
# one pair 20211100800
# ['2h', '5d', '3h', 'Tc', '8d'] ['2c', 'Js']
# 0.06633302400000005
# two pair 31312090000
# ['3h', 'Qs', 'Kc', '4c', 'Kd'] ['Qd', '9s']
# 0.6600000000000001
# two pair 31208110000
# ['6h', 'Qc', '7c', 'Js', 'Qh'] ['8d', '8s']
# 0.6600000000000001
# nothing 11413110806
# ['4c', '8c', '6h', 'Ks', 'As'] ['Jd', '2h']
# -0.19760667581999997
# one pair 20512100900
# ['Tc', '8h', 'Qs', '9h', '5d'] ['5c', '7d']
# 0.075363027
# nothing 11210090807
# ['4d', '9d', '8s', '7d', '2c'] ['Th', 'Qh']
# -0.20369727578999997
# one pair 21013120800
# ['8c', '4d', '2c', 'Kc', 'Qh'] ['Tc', 'Td']
# 0.09039362400000006
# nothing 11412100908
# ['3s', 'Ac', '9c', 'Qh', 'Ts'] ['7c', '8c']
# -0.19763697275999997
# nothing 11413120907
# ['7d', '9d', '5h', 'Kh', '3d'] ['Ah', 'Qs']
# -0.19760637278999998
# one pair 20614090400
# ['4d', '6c', '3s', '6s', '2d'] ['9c', 'As']
# 0.07842271200000006
# one pair 21413090800
# ['Ad', '9s', 'Ac', '6s', 'Kc'] ['8h', '7d']
# 0.10239272400000005
# flush 61412111008
# ['Jd', 'Kh', 'Qd', '5d', '8d'] ['Ad', 'Td']
# 0.96

# %%
print(dict)
# Out:
# {('same', '2', '3'): 0.3309, ('same', '2', '4'): 0.3392, ('same', '2', '5'): 0.3493, ('same', '2', '6'): 0.34840000000000004, ('same', '2', '7'): 0.3544, ('same', '2', '8'): 0.3768, ('same', '2', '9'): 0.3997, ('same', '2', 'T'): 0.4254, ('same', '2', 'J'): 0.452, ('same', '2', 'Q'): 0.48100000000000004, ('same', '2', 'K'): 0.5124, ('same', '2', 'A'): 0.5550999999999999, ('same', '3', '4'): 0.35729999999999995, ('same', '3', '5'): 0.3676, ('same', '3', '6'): 0.3669, ('same', '3', '7'): 0.373, ('same', '3', '8'): 0.38280000000000003, ('same', '3', '9'): 0.4081, ('same', '3', 'T'): 0.4338, ('same', '3', 'J'): 0.4604, ('same', '3', 'Q'): 0.4894, ('same', '3', 'K'): 0.5207, ('same', '3', 'A'): 0.5634, ('same', '4', '5'): 0.38530000000000003, ('same', '4', '6'): 0.3848, ('same', '4', '7'): 0.3911, ('same', '4', '8'): 0.401, ('same', '4', '9'): 0.41409999999999997, ('same', '4', 'T'): 0.442, ('same', '4', 'J'): 0.46869999999999995, ('same', '4', 'Q'): 0.4976, ('same', '4', 'K'): 0.5289, ('same', '4', 'A'): 0.5714, ('same', '5', '6'): 0.4035, ('same', '5', '7'): 0.40979999999999994, ('same', '5', '8'): 0.4199, ('same', '5', '9'): 0.43310000000000004, ('same', '5', 'T'): 0.44939999999999997, ('same', '5', 'J'): 0.4782, ('same', '5', 'Q'): 0.5071, ('same', '5', 'K'): 0.5383, ('same', '5', 'A'): 0.5806, ('same', '6', '7'): 0.42829999999999996, ('same', '6', '8'): 0.4382, ('same', '6', '9'): 0.4515, ('same', '6', 'T'): 0.46799999999999997, ('same', '6', 'J'): 0.4857, ('same', '6', 'Q'): 0.5168, ('same', '6', 'K'): 0.5479999999999999, ('same', '6', 'A'): 0.5818, ('same', '7', '8'): 0.4568, ('same', '7', '9'): 0.46990000000000004, ('same', '7', 'T'): 0.4865, ('same', '7', 'J'): 0.5045000000000001, ('same', '7', 'Q'): 0.5252, ('same', '7', 'K'): 0.5585, ('same', '7', 'A'): 0.5939, ('same', '8', '9'): 0.4886, ('same', '8', 'T'): 0.5051, ('same', '8', 'J'): 0.5231, ('same', '8', 'Q'): 0.5442, ('same', '8', 'K'): 0.5679, ('same', '8', 'A'): 0.6051, ('same', '9', 'T'): 0.5238, ('same', '9', 'J'): 0.5411, ('same', '9', 'Q'): 0.5622, ('same', '9', 'K'): 0.5864, ('same', '9', 'A'): 0.6151, ('same', 'T', 'J'): 0.5615, ('same', 'T', 'Q'): 0.5817, ('same', 'T', 'K'): 0.6059, ('same', 'T', 'A'): 0.6349, ('same', 'J', 'Q'): 0.5907, ('same', 'J', 'K'): 0.6148, ('same', 'J', 'A'): 0.644, ('same', 'Q', 'K'): 0.6241, ('same', 'Q', 'A'): 0.6531, ('same', 'K', 'A'): 0.6622, ('diff', '2', '3'): 0.2924, ('diff', '2', '4'): 0.3012, ('diff', '2', '5'): 0.3119, ('diff', '2', '6'): 0.31079999999999997, ('diff', '2', '7'): 0.3171, ('diff', '2', '8'): 0.34090000000000004, ('diff', '2', '9'): 0.3652, ('diff', '2', 'T'): 0.3924, ('diff', '2', 'J'): 0.4205, ('diff', '2', 'Q'): 0.4511, ('diff', '2', 'K'): 0.4842, ('diff', '2', 'A'): 0.5295000000000001, ('diff', '3', '3'): 0.5284, ('diff', '3', '4'): 0.3207, ('diff', '3', '5'): 0.33159999999999995, ('diff', '3', '6'): 0.3307, ('diff', '3', '7'): 0.3372, ('diff', '3', '8'): 0.3475, ('diff', '3', '9'): 0.3743, ('diff', '3', 'T'): 0.40159999999999996, ('diff', '3', 'J'): 0.42969999999999997, ('diff', '3', 'Q'): 0.46020000000000005, ('diff', '3', 'K'): 0.49329999999999996, ('diff', '3', 'A'): 0.5386, ('diff', '4', '4'): 0.5626, ('diff', '4', '5'): 0.3507, ('diff', '4', '6'): 0.35, ('diff', '4', '7'): 0.3566, ('diff', '4', '8'): 0.3671, ('diff', '4', '9'): 0.3809, ('diff', '4', 'T'): 0.4106, ('diff', '4', 'J'): 0.4387, ('diff', '4', 'Q'): 0.4692, ('diff', '4', 'K'): 0.5023, ('diff', '4', 'A'): 0.5473, ('diff', '5', '5'): 0.5964, ('diff', '5', '6'): 0.3701, ('diff', '5', '7'): 0.37670000000000003, ('diff', '5', '8'): 0.3874, ('diff', '5', '9'): 0.4014, ('diff', '5', 'T'): 0.41859999999999997, ('diff', '5', 'J'): 0.449, ('diff', '5', 'Q'): 0.4796, ('diff', '5', 'K'): 0.5125, ('diff', '5', 'A'): 0.5574, ('diff', '6', '6'): 0.627, ('diff', '6', '7'): 0.39649999999999996, ('diff', '6', '8'): 0.40700000000000003, ('diff', '6', '9'): 0.42100000000000004, ('diff', '6', 'T'): 0.4385, ('diff', '6', 'J'): 0.4571, ('diff', '6', 'Q'): 0.4 ...
